# %%
import requests
import os
import pandas as pd
import json

# %%
api_key = os.environ["FOURSQUARE_API_KEY"]

def search_foursquare(lat, lon, category='19066,19043,19054,19066,13000', radius=1000, limit=50):
    """
    Queries Foursquare Places API for venues near a given lat/lon.
    Default category is '13018' = Museum
    """
    url = 'https://api.foursquare.com/v3/places/search'
    headers = {
        "Accept": "application/json",
        "Authorization": api_key
    }
    params = {
        "ll": f"{lat},{lon}",
        "radius": radius,
        "limit": limit,
        "categories": category,
        "fields": "name,distance,popularity,rating,categories,geocodes"
    }
    
    response = requests.get(url, headers=headers, params=params)
    
    print("Status code:", response.status_code)
    print("Response text (first 300 chars):", response.text[:300])
    
    if response.status_code != 200:
        print(f"Error: {response.status_code} — {response.text}")
        return None
    
    data = response.json()
    
    print(json.dumps(data, indent=4))



    #Used the get() method because if "results" doesn't exist, it assigns an empty list instead — avoiding a crash.
    places = data.get("results", [])


    final_places = []
    for place in places:
        final_places.append({
            'distance': place.get('distance'),
            'name': place.get('name'),
            'popularity': place.get('popularity'),
            'rating': place.get('rating'),
            'latitude': place.get('geocodes', {}).get('main', {}).get('latitude'),
            'longitude': place.get('geocodes', {}).get('main', {}).get('longitude'),
            'category': place.get('categories', [{}])[0].get('name') if place.get('categories') else None
        })

    df = pd.DataFrame(final_places)


    return df

# %%
search_foursquare(49.28803,-123.142135)
# Out:
# Status code: 200
# Response text (first 300 chars): {"results":[{"categories":[{"id":13303,"name":"Mexican Restaurant","short_name":"Mexican","plural_name":"Mexican Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/mexican_","suffix":".png"}},{"id":13314,"name":"New American Restaurant","short_name":"New American","plural_nam
# {
#     "results": [
#         {
#             "categories": [
#                 {
#                     "id": 13303,
#                     "name": "Mexican Restaurant",
#                     "short_name": "Mexican",
#                     "plural_name": "Mexican Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/mexican_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13314,
#                     "name": "New American Restaurant",
#                     "short_name": "New American",
#                     "plural_name": "New American Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/newamerican_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 149,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.28666,
#                     "longitude": -123.14278
#                 },
#                 "roof": {
#                     "latitude": 49.28666,
#                     "longitude": -123.14278
#                 }
#             },
#             "name": "Cactus Club Cafe",
#             "popularity": 0.9824711415134673,
#             "rating": 9.0
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13006,
#                     "name": "Beer Bar",
#                     "short_name": "Beer Bar",
#                     "plural_name": "Beer Bars",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/nightlife/pub_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13065,
#                     "name": "Restaurant",
#                     "short_name": "Restaurant",
#                     "plural_name": "Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/default_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 155,
#             "geocodes": {
#                 "drop_off": {
#                     "latitude": 49.286665,
#                     "longitude": -123.142408
#                 },
#                 "main": {
#                     "latitude": 49.286629,
#                     "longitude": -123.14221
#                 },
#                 "roof": {
#                     "latitude": 49.286629,
#                     "longitude": -123.14221
#                 }
#             },
#             "name": "CRAFT Beer Market English Bay",
#             "popularity": 0.9862412064207703,
#             "rating": 8.6
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13099,
#                     "name": "Chinese Restaurant",
#                     "short_name": "Chinese",
#                     "plural_name": "Chinese Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/asian_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 179,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.288425,
#                     "longitude": -123.139849
#                 },
#                 "roof": {
#                     "latitude": 49.288425,
#                     "longitude": -123.139849
#                 }
#             },
#             "name": "Legendary Noodle House",
#             "popularity": 0.9736225011983883,
#             "rating": 8.6
#         },
#         {
#             "categories": [
#                 {
#                     "id": 10047,
#                     "name": "Public Art",
#                     "short_name": "Public Art",
#                     "plural_name": "Public Art",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13065,
#                     "name": "Restaurant",
#                     "short_name": "Restaurant",
#                     "plural_name": "Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/default_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 16016,
#                     "name": "Fountain",
#                     "short_name": "Fountain",
#                     "plural_name": "Fountains",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 19014,
#                     "name": "Hotel",
#                     "short_name": "Hotel",
#                     "plural_name": "Hotels",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/travel/hotel_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 425,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.284303,
#                     "longitude": -123.143552
#                 }
#             },
#             "name": "The Inukshuk",
#             "popularity": 0.9911254485859018,
#             "rating": 9.2
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13276,
#                     "name": "Sushi Restaurant",
#                     "short_name": "Sushi",
#                     "plural_name": "Sushi Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/sushi_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13347,
#                     "name": "Tapas Restaurant",
#                     "short_name": "Tapas",
#                     "plural_name": "Tapas Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/tapas_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 463,
#             "geocodes": {
#                 "drop_off": {
#                     "latitude": 49.290524,
#                     "longitude": -123.136877
#                 },
#                 "main": {
#                     "latitude": 49.290643,
#                     "longitude": -123.136956
#                 },
#                 "roof": {
#                     "latitude": 49.290643,
#                     "longitude": -123.136956
#                 }
#             },
#             "name": "Kingyo Izakaya",
#             "popularity": 0.9795172762252711,
#             "rating": 9.1
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13035,
#                     "name": "Coffee Shop",
#                     "short_name": "Coffee Shop",
#                     "plural_name": "Coffee Shops",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13065,
#                     "name": "Restaurant",
#                     "short_name": "Restaurant",
#                     "plural_name": "Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/default_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 231,
#             "geocodes": {
#                 "drop_off": {
#                     "latitude": 49.286094,
#                     "longitude": -123.140469
#                 },
#                 "main": {
#                     "latitude": 49.286217,
#                     "longitude": -123.140552
#                 },
#                 "roof": {
#                     "latitude": 49.286217,
#                     "longitude": -123.140552
#                 }
#             },
#             "name": "JJ Bean Coffee Roasters",
#             "popularity": 0.9656289271509451,
#             "rating": 8.3
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13034,
#                     "name": "Caf\u00e9",
#                     "short_name": "Caf\u00e9",
#                     "plural_name": "Caf\u00e9s",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/cafe_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13035,
#                     "name": "Coffee Shop",
#                     "short_name": "Coffee Shop",
#                     "plural_name": "Coffee Shops",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13065,
#                     "name": "Restaurant",
#                     "short_name": "Restaurant",
#                     "plural_name": "Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/default_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 607,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.286624,
#                     "longitude": -123.133935
#                 },
#                 "roof": {
#                     "latitude": 49.286624,
#                     "longitude": -123.133935
#                 }
#             },
#             "name": "Greenhorn Cafe",
#             "popularity": 0.9546296656172671,
#             "rating": 8.7
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13034,
#                     "name": "Caf\u00e9",
#                     "short_name": "Caf\u00e9",
#                     "plural_name": "Caf\u00e9s",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/cafe_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13035,
#                     "name": "Coffee Shop",
#                     "short_name": "Coffee Shop",
#                     "plural_name": "Coffee Shops",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13051,
#                     "name": "Fish and Chips Shop",
#                     "short_name": "Fish and Chips Shop",
#                     "plural_name": "Fish and Chips Shops",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/fishandchips_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 233,
#             "geocodes": {
#                 "drop_off": {
#                     "latitude": 49.286278,
#                     "longitude": -123.140336
#                 },
#                 "main": {
#                     "latitude": 49.286418,
#                     "longitude": -123.140245
#                 },
#                 "roof": {
#                     "latitude": 49.286418,
#                     "longitude": -123.140245
#                 }
#             },
#             "name": "Red Umbrella Cafe",
#             "popularity": 0.9664062601215231,
#             "rating": 7.9
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13272,
#                     "name": "Ramen Restaurant",
#                     "short_name": "Ramen",
#                     "plural_name": "Ramen Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/ramen_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13276,
#                     "name": "Sushi Restaurant",
#                     "short_name": "Sushi",
#                     "plural_name": "Sushi Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/sushi_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 668,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.290258,
#                     "longitude": -123.13384
#                 },
#                 "roof": {
#                     "latitude": 49.290258,
#                     "longitude": -123.13384
#                 }
#             },
#             "name": "Hokkaido Ramen Santouka",
#             "popularity": 0.9700338139842202,
#             "rating": 8.7
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13046,
#                     "name": "Ice Cream Parlor",
#                     "short_name": "Ice Cream",
#                     "plural_name": "Ice Cream Parlors",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/icecream_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 163,
#             "geocodes": {
#                 "drop_off": {
#                     "latitude": 49.288436,
#                     "longitude": -123.140022
#                 },
#                 "main": {
#                     "latitude": 49.288276,
#                     "longitude": -123.139917
#                 },
#                 "roof": {
#                     "latitude": 49.288276,
#                     "longitude": -123.139917
#                 }
#             },
#             "name": "D'oro Gelato e Caff\u00e8",
#             "popularity": 0.9524790443986682,
#             "rating": 7.7
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13018,
#                     "name": "Pub",
#                     "short_name": "Pub",
#                     "plural_name": "Pubs",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/nightlife/pub_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13065,
#                     "name": "Restaurant",
#                     "short_name": "Restaurant",
#                     "plural_name": "Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/default_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 139,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.286922,
#                     "longitude": -123.140937
#                 },
#                 "roof": {
#                     "latitude": 49.286922,
#                     "longitude": -123.140937
#                 }
#             },
#             "name": "The Park at English Bay",
#             "popularity": 0.9854250068016635,
#             "rating": 7.6
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13236,
#                     "name": "Italian Restaurant",
#                     "short_name": "Italian",
#                     "plural_name": "Italian Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/italian_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 636,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.29174,
#                     "longitude": -123.135346
#                 },
#                 "roof": {
#                     "latitude": 49.29174,
#                     "longitude": -123.135346
#                 }
#             },
#             "name": "Nook",
#             "popularity": 0.9409874719836242,
#             "rating": 8.4
#         },
#         {
#             "categories": [
#                 {
#                     "id": 10000,
#                     "name": "Arts and Entertainment",
#                     "short_name": "Arts & Entertainment",
#                     "plural_name": "Arts and Entertainment",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13022,
#                     "name": "Sports Bar",
#                     "short_name": "Sports Bar",
#                     "plural_name": "Sports Bars",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/nightlife/sportsbar_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13065,
#                     "name": "Restaurant",
#                     "short_name": "Restaurant",
#                     "plural_name": "Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/default_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 840,
#             "geocodes": {
#                 "drop_off": {
#                     "latitude": 49.28247,
#                     "longitude": -123.134418
#                 },
#                 "main": {
#                     "latitude": 49.282285,
#                     "longitude": -123.134538
#                 },
#                 "roof": {
#                     "latitude": 49.282285,
#                     "longitude": -123.134538
#                 }
#             },
#             "name": "Score on Davie",
#             "popularity": 0.9781439879772501,
#             "rating": 8.7
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13272,
#                     "name": "Ramen Restaurant",
#                     "short_name": "Ramen",
#                     "plural_name": "Ramen Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/ramen_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 952,
#             "geocodes": {
#                 "drop_off": {
#                     "latitude": 49.287359,
#                     "longitude": -123.129071
#                 },
#                 "main": {
#                     "latitude": 49.287499,
#                     "longitude": -123.12898
#                 },
#                 "roof": {
#                     "latitude": 49.287499,
#                     "longitude": -123.12898
#                 }
#             },
#             "name": "Ramen Danbo - Robson",
#             "popularity": 0.9960226463005428,
#             "rating": 9.0
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13263,
#                     "name": "Japanese Restaurant",
#                     "short_name": "Japanese",
#                     "plural_name": "Japanese Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/japanese_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 724,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.291333,
#                     "longitude": -123.134825
#                 },
#                 "roof": {
#                     "latitude": 49.291333,
#                     "longitude": -123.134825
#                 }
#             },
#             "name": "Saku",
#             "popularity": 0.9744646119165145,
#             "rating": 8.4
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13272,
#                     "name": "Ramen Restaurant",
#                     "short_name": "Ramen",
#                     "plural_name": "Ramen Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/ramen_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 686,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.290515,
#                     "longitude": -123.133538
#                 },
#                 "roof": {
#                     "latitude": 49.290515,
#                     "longitude": -123.133538
#                 }
#             },
#             "name": "Marutama Ra-men",
#             "popularity": 0.9892728050060243,
#             "rating": 8.3
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13065,
#                     "name": "Restaurant",
#                     "short_name": "Restaurant",
#                     "plural_name": "Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/default_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13145,
#                     "name": "Fast Food Restaurant",
#                     "short_name": "Fast Food",
#                     "plural_name": "Fast Food Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/fastfood_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 912,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.282095,
#                     "longitude": -123.133548
#                 },
#                 "roof": {
#                     "latitude": 49.282095,
#                     "longitude": -123.133548
#                 }
#             },
#             "name": "La Belle Patate",
#             "popularity": 0.9857100288908754,
#             "rating": 8.6
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13125,
#                     "name": "Shanghai Restaurant",
#                     "short_name": "Shanghai",
#                     "plural_name": "Shanghai Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/asian_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 646,
#             "geocodes": {
#                 "drop_off": {
#                     "latitude": 49.290627,
#                     "longitude": -123.134125
#                 },
#                 "main": {
#                     "latitude": 49.290752,
#                     "longitude": -123.134045
#                 },
#                 "roof": {
#                     "latitude": 49.290752,
#                     "longitude": -123.134045
#                 }
#             },
#             "name": "Dinesty Chinese Restaurant",
#             "popularity": 0.9762395221993341,
#             "rating": 8.1
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13276,
#                     "name": "Sushi Restaurant",
#                     "short_name": "Sushi",
#                     "plural_name": "Sushi Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/sushi_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 987,
#             "geocodes": {
#                 "drop_off": {
#                     "latitude": 49.281454,
#                     "longitude": -123.132848
#                 },
#                 "main": {
#                     "latitude": 49.28157,
#                     "longitude": -123.132773
#                 },
#                 "roof": {
#                     "latitude": 49.28157,
#                     "longitude": -123.132773
#                 }
#             },
#             "name": "Tom Sushi",
#             "popularity": 0.9749698783473901,
#             "rating": 8.7
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13018,
#                     "name": "Pub",
#                     "short_name": "Pub",
#                     "plural_name": "Pubs",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/nightlife/pub_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13065,
#                     "name": "Restaurant",
#                     "short_name": "Restaurant",
#                     "plural_name": "Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/default_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 101,
#             "geocodes": {
#                 "drop_off": {
#                     "latitude": 49.287192,
#                     "longitude": -123.141737
#                 },
#                 "main": {
#                     "latitude": 49.287036,
#                     "longitude": -123.141839
#                 },
#                 "roof": {
#                     "latitude": 49.287036,
#                     "longitude": -123.141839
#                 }
#             },
#             "name": "The Calling Public House",
#             "popularity": 0.9610037959760063,
#             "rating": 7.3
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13035,
#                     "name": "Coffee Shop",
#                     "short_name": "Coffee Shop",
#                     "plural_name": "Coffee Shops",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13065,
#                     "name": "Restaurant",
#                     "short_name": "Restaurant",
#                     "plural_name": "Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/default_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 418,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.290242,
#                     "longitude": -123.137571
#                 },
#                 "roof": {
#                     "latitude": 49.290242,
#                     "longitude": -123.137571
#                 }
#             },
#             "name": "Blenz Coffee",
#             "popularity": 0.9758638112635547,
#             "rating": 7.6
#         },
#         {
#             "categories": [
#                 {
#                     "id": 10032,
#                     "name": "Night Club",
#                     "short_name": "Night Club",
#                     "plural_name": "Night Clubs",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/nightlife/nightclub_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13011,
#                     "name": "Gay Bar",
#                     "short_name": "Gay Bar",
#                     "plural_name": "Gay Bars",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/nightlife/gaybar_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13016,
#                     "name": "Lounge",
#                     "short_name": "Lounge",
#                     "plural_name": "Lounges",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/nightlife/default_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 977,
#             "geocodes": {
#                 "drop_off": {
#                     "latitude": 49.281517,
#                     "longitude": -123.132945
#                 },
#                 "main": {
#                     "latitude": 49.281647,
#                     "longitude": -123.132861
#                 },
#                 "roof": {
#                     "latitude": 49.281647,
#                     "longitude": -123.132861
#                 }
#             },
#             "name": "1181 Lounge",
#             "popularity": 0.9574021532123285,
#             "rating": 8.2
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13034,
#                     "name": "Caf\u00e9",
#                     "short_name": "Caf\u00e9",
#                     "plural_name": "Caf\u00e9s",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/cafe_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13035,
#                     "name": "Coffee Shop",
#                     "short_name": "Coffee Shop",
#                     "plural_name": "Coffee Shops",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13065,
#                     "name": "Restaurant",
#                     "short_name": "Restaurant",
#                     "plural_name": "Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/default_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 852,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.282224,
#                     "longitude": -123.134289
#                 },
#                 "roof": {
#                     "latitude": 49.282224,
#                     "longitude": -123.134289
#                 }
#             },
#             "name": "Melriches Coffeehouse",
#             "popularity": 0.9724435461930118,
#             "rating": 8.0
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13065,
#                     "name": "Restaurant",
#                     "short_name": "Restaurant",
#                     "plural_name": "Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/default_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 908,
#             "geocodes": {
#                 "drop_off": {
#                     "latitude": 49.287673,
#                     "longitude": -123.129554
#                 },
#                 "main": {
#                     "latitude": 49.287551,
#                     "longitude": -123.129634
#                 },
#                 "roof": {
#                     "latitude": 49.287551,
#                     "longitude": -123.129634
#                 }
#             },
#             "name": "Chez Cora",
#             "popularity": 0.9757213002189488,
#             "rating": 8.0
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13011,
#                     "name": "Gay Bar",
#                     "short_name": "Gay Bar",
#                     "plural_name": "Gay Bars",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/nightlife/gaybar_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 956,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.281565,
#                     "longitude": -123.133421
#                 },
#                 "roof": {
#                     "latitude": 49.281565,
#                     "longitude": -123.133421
#                 }
#             },
#             "name": "Xy",
#             "popularity": 0.40500343322062005,
#             "rating": 7.8
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13064,
#                     "name": "Pizzeria",
#                     "short_name": "Pizza",
#                     "plural_name": "Pizzerias",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/pizza_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 160,
#             "geocodes": {
#                 "drop_off": {
#                     "latitude": 49.288447,
#                     "longitude": -123.140006
#                 },
#                 "main": {
#                     "latitude": 49.2886,
#                     "longitude": -123.140107
#                 },
#                 "roof": {
#                     "latitude": 49.2886,
#                     "longitude": -123.140107
#                 }
#             },
#             "name": "Nat's Pizzeria",
#             "popularity": 0.9228497026701388,
#             "rating": 6.9
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13223,
#                     "name": "South Indian Restaurant",
#                     "short_name": "South Indian",
#                     "plural_name": "South Indian Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/default_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 885,
#             "geocodes": {
#                 "drop_off": {
#                     "latitude": 49.282088,
#                     "longitude": -123.133828
#                 },
#                 "main": {
#                     "latitude": 49.282249,
#                     "longitude": -123.133723
#                 },
#                 "roof": {
#                     "latitude": 49.282249,
#                     "longitude": -123.133723
#                 }
#             },
#             "name": "Davie Dosa Co",
#             "popularity": 0.9014212237812067,
#             "rating": 7.6
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13068,
#                     "name": "American Restaurant",
#                     "short_name": "American",
#                     "plural_name": "American Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/default_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13145,
#                     "name": "Fast Food Restaurant",
#                     "short_name": "Fast Food",
#                     "plural_name": "Fast Food Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/fastfood_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 318,
#             "geocodes": {
#                 "drop_off": {
#                     "latitude": 49.289508,
#                     "longitude": -123.138405
#                 },
#                 "main": {
#                     "latitude": 49.28964,
#                     "longitude": -123.138493
#                 },
#                 "roof": {
#                     "latitude": 49.28964,
#                     "longitude": -123.138493
#                 }
#             },
#             "name": "A&W Restaurant",
#             "popularity": 0.9628434840063741,
#             "rating": 7.1
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13029,
#                     "name": "Brewery",
#                     "short_name": "Brewery",
#                     "plural_name": "Breweries",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/brewery_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13065,
#                     "name": "Restaurant",
#                     "short_name": "Restaurant",
#                     "plural_name": "Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/default_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 537,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.292295,
#                     "longitude": -123.146508
#                 },
#                 "roof": {
#                     "latitude": 49.292295,
#                     "longitude": -123.146508
#                 }
#             },
#             "name": "Stanley Park Brewing Restaurant & Brewpub",
#             "popularity": 0.9735447679013305,
#             "rating": 7.3
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13034,
#                     "name": "Caf\u00e9",
#                     "short_name": "Caf\u00e9",
#                     "plural_name": "Caf\u00e9s",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/cafe_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13065,
#                     "name": "Restaurant",
#                     "short_name": "Restaurant",
#                     "plural_name": "Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/default_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 974,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.291395,
#                     "longitude": -123.129719
#                 },
#                 "roof": {
#                     "latitude": 49.291395,
#                     "longitude": -123.129719
#                 }
#             },
#             "name": "Breaking Bean",
#             "popularity": 0.9779626102841152,
#             "rating": 7.5
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13299,
#                     "name": "Malay Restaurant",
#                     "short_name": "Malay",
#                     "plural_name": "Malay Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/malaysian_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 625,
#             "geocodes": {
#                 "drop_off": {
#                     "latitude": 49.291239,
#                     "longitude": -123.135077
#                 },
#                 "main": {
#                     "latitude": 49.291374,
#                     "longitude": -123.13499
#                 },
#                 "roof": {
#                     "latitude": 49.291374,
#                     "longitude": -123.13499
#                 }
#             },
#             "name": "Banana Leaf",
#             "popularity": 0.9711220801430293,
#             "rating": 7.1
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13034,
#                     "name": "Caf\u00e9",
#                     "short_name": "Caf\u00e9",
#                     "plural_name": "Caf\u00e9s",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/cafe_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13065,
#                     "name": "Restaurant",
#                     "short_name": "Restaurant",
#                     "plural_name": "Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/default_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 579,
#             "geocodes": {
#                 "drop_off": {
#                     "latitude": 49.291197,
#                     "longitude": -123.135865
#                 },
#                 "main": {
#                     "latitude": 49.291338,
#                     "longitude": -123.135961
#                 },
#                 "roof": {
#                     "latitude": 49.291338,
#                     "longitude": -123.135961
#                 }
#             },
#             "name": "Breka Bakery and Cafe",
#             "popularity": 0.9912031818829595,
#             "rating": 6.9
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13032,
#                     "name": "Cafe, Coffee, and Tea House",
#                     "short_name": "Cafe, Coffee, and Tea House",
#                     "plural_name": "Cafes, Coffee, and Tea Houses",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13043,
#                     "name": "Donut Shop",
#                     "short_name": "Donuts",
#                     "plural_name": "Donut Shops",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/donuts_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13065,
#                     "name": "Restaurant",
#                     "short_name": "Restaurant",
#                     "plural_name": "Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/default_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 260,
#             "geocodes": {
#                 "drop_off": {
#                     "latitude": 49.289117,
#                     "longitude": -123.138994
#                 },
#                 "main": {
#                     "latitude": 49.289295,
#                     "longitude": -123.139112
#                 },
#                 "roof": {
#                     "latitude": 49.289295,
#                     "longitude": -123.139112
#                 }
#             },
#             "name": "Tim Hortons",
#             "popularity": 0.9802816536463395,
#             "rating": 6.5
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13039,
#                     "name": "Deli",
#                     "short_name": "Deli",
#                     "plural_name": "Delis",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/deli_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 17077,
#                     "name": "Meat and Seafood Store",
#                     "short_name": "Meat and Seafood Store",
#                     "plural_name": "Meat and Seafood Stores",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 892,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.282028,
#                     "longitude": -123.133948
#                 },
#                 "roof": {
#                     "latitude": 49.282028,
#                     "longitude": -123.133948
#                 }
#             },
#             "name": "European Delicatessen",
#             "popularity": 0.8531618018578258,
#             "rating": 6.7
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13276,
#                     "name": "Sushi Restaurant",
#                     "short_name": "Sushi",
#                     "plural_name": "Sushi Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/sushi_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 220,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.286439,
#                     "longitude": -123.140328
#                 },
#                 "roof": {
#                     "latitude": 49.286439,
#                     "longitude": -123.140328
#                 }
#             },
#             "name": "Yummy to Go",
#             "popularity": 0.9730135903714356,
#             "rating": 5.8
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13065,
#                     "name": "Restaurant",
#                     "short_name": "Restaurant",
#                     "plural_name": "Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/default_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 16028,
#                     "name": "Nature Preserve",
#                     "short_name": "Preserve",
#                     "plural_name": "Nature Preserves",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/parks_outdoors/naturepreserve_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 16032,
#                     "name": "Park",
#                     "short_name": "Park",
#                     "plural_name": "Parks",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 18000,
#                     "name": "Sports and Recreation",
#                     "short_name": "Sports and Recreation",
#                     "plural_name": "Sports and Recreation",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 19014,
#                     "name": "Hotel",
#                     "short_name": "Hotel",
#                     "plural_name": "Hotels",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/travel/hotel_",
# ...
#                     "latitude": 49.288997,
#                     "longitude": -123.13211
#                 },
#                 "roof": {
#                     "latitude": 49.288997,
#                     "longitude": -123.13211
#                 }
#             },
#             "name": "Chongqing Liuyishou HotPot Restaurant",
#             "popularity": 0.956469353647635,
#             "rating": 6.1
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13034,
#                     "name": "Caf\u00e9",
#                     "short_name": "Caf\u00e9",
#                     "plural_name": "Caf\u00e9s",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/cafe_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13035,
#                     "name": "Coffee Shop",
#                     "short_name": "Coffee Shop",
#                     "plural_name": "Coffee Shops",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 931,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.281941,
#                     "longitude": -123.133372
#                 },
#                 "roof": {
#                     "latitude": 49.281941,
#                     "longitude": -123.133372
#                 }
#             },
#             "name": "Blenz Coffee",
#             "popularity": 0.9662896601759363,
#             "rating": 6.2
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13012,
#                     "name": "Hookah Bar",
#                     "short_name": "Hookah Bar",
#                     "plural_name": "Hookah Bars",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/nightlife/hookahbar_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 424,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.284303,
#                     "longitude": -123.140875
#                 },
#                 "roof": {
#                     "latitude": 49.284303,
#                     "longitude": -123.140875
#                 }
#             },
#             "name": "The Gazebo by English Bay",
#             "popularity": 0.7668519310246544
#         },
#         {
#             "categories": [
#                 {
#                     "id": 16020,
#                     "name": "Historic and Protected Site",
#                     "short_name": "Historic and Protected Site",
#                     "plural_name": "Historic and Protected Sites",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/arts_entertainment/historicsite_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13065,
#                     "name": "Restaurant",
#                     "short_name": "Restaurant",
#                     "plural_name": "Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/default_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 428,
#             "geocodes": {
#                 "drop_off": {
#                     "latitude": 49.285123,
#                     "longitude": -123.138522
#                 },
#                 "main": {
#                     "latitude": 49.284915,
#                     "longitude": -123.138656
#                 },
#                 "roof": {
#                     "latitude": 49.284915,
#                     "longitude": -123.138656
#                 }
#             },
#             "name": "Gabriola House",
#             "popularity": 0.9120706854781245
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13079,
#                     "name": "Brazilian Restaurant",
#                     "short_name": "Brazilian",
#                     "plural_name": "Brazilian Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/argentinian_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 454,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.284704,
#                     "longitude": -123.138476
#                 },
#                 "roof": {
#                     "latitude": 49.284704,
#                     "longitude": -123.138476
#                 }
#             },
#             "name": "Uno Brazilian Snacks",
#             "popularity": 0.14980501897988002
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13309,
#                     "name": "Middle Eastern Restaurant",
#                     "short_name": "Middle Eastern",
#                     "plural_name": "Middle Eastern Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/middleeastern_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 527,
#             "geocodes": {
#                 "drop_off": {
#                     "latitude": 49.290851,
#                     "longitude": -123.136384
#                 },
#                 "main": {
#                     "latitude": 49.291029,
#                     "longitude": -123.136502
#                 },
#                 "roof": {
#                     "latitude": 49.291029,
#                     "longitude": -123.136502
#                 }
#             },
#             "name": "Habibi Donair",
#             "popularity": 0.7317164807545312
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13303,
#                     "name": "Mexican Restaurant",
#                     "short_name": "Mexican",
#                     "plural_name": "Mexican Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/mexican_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 600,
#             "geocodes": {
#                 "drop_off": {
#                     "latitude": 49.291323,
#                     "longitude": -123.135679
#                 },
#                 "main": {
#                     "latitude": 49.291524,
#                     "longitude": -123.135814
#                 },
#                 "roof": {
#                     "latitude": 49.291524,
#                     "longitude": -123.135814
#                 }
#             },
#             "name": "Holy Guacamole",
#             "popularity": 0.8859522976667056
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13002,
#                     "name": "Bakery",
#                     "short_name": "Bakery",
#                     "plural_name": "Bakeries",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/bakery_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13039,
#                     "name": "Deli",
#                     "short_name": "Deli",
#                     "plural_name": "Delis",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/deli_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13040,
#                     "name": "Dessert Shop",
#                     "short_name": "Desserts",
#                     "plural_name": "Dessert Shops",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/dessert_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 636,
#             "geocodes": {
#                 "drop_off": {
#                     "latitude": 49.290602,
#                     "longitude": -123.134086
#                 },
#                 "main": {
#                     "latitude": 49.290453,
#                     "longitude": -123.134182
#                 },
#                 "roof": {
#                     "latitude": 49.290453,
#                     "longitude": -123.134182
#                 }
#             },
#             "name": "Cobs Bread",
#             "popularity": 0.961159262570122
#         }
#     ],
#     "context": {
#         "geo_bounds": {
#             "circle": {
#                 "center": {
#                     "latitude": 49.28803,
#                     "longitude": -123.142135
#                 },
#                 "radius": 1000
#             }
#         }
#     }
# }
#     distance                                       name  popularity  rating  \
# 0        149                           Cactus Club Cafe    0.982471     9.0
# 1        155              CRAFT Beer Market English Bay    0.986241     8.6
# 2        179                     Legendary Noodle House    0.973623     8.6
# 3        425                               The Inukshuk    0.991125     9.2
# 4        463                             Kingyo Izakaya    0.979517     9.1
# 5        231                    JJ Bean Coffee Roasters    0.965629     8.3
# 6        607                             Greenhorn Cafe    0.954630     8.7
# 7        233                          Red Umbrella Cafe    0.966406     7.9
# 8        668                    Hokkaido Ramen Santouka    0.970034     8.7
# 9        163                       D'oro Gelato e Caffè    0.952479     7.7
# 10       139                    The Park at English Bay    0.985425     7.6
# 11       636                                       Nook    0.940987     8.4
# 12       840                             Score on Davie    0.978144     8.7
# 13       952                       Ramen Danbo - Robson    0.996023     9.0
# 14       724                                       Saku    0.974465     8.4
# 15       686                            Marutama Ra-men    0.989273     8.3
# 16       912                            La Belle Patate    0.985710     8.6
# 17       646                 Dinesty Chinese Restaurant    0.976240     8.1
# 18       987                                  Tom Sushi    0.974970     8.7
# 19       101                   The Calling Public House    0.961004     7.3
# 20       418                               Blenz Coffee    0.975864     7.6
# 21       977                                1181 Lounge    0.957402     8.2
# 22       852                      Melriches Coffeehouse    0.972444     8.0
# 23       908                                  Chez Cora    0.975721     8.0
# 24       956                                         Xy    0.405003     7.8
# 25       160                             Nat's Pizzeria    0.922850     6.9
# 26       885                              Davie Dosa Co    0.901421     7.6
# 27       318                             A&W Restaurant    0.962843     7.1
# 28       537  Stanley Park Brewing Restaurant & Brewpub    0.973545     7.3
# 29       974                              Breaking Bean    0.977963     7.5
# 30       625                                Banana Leaf    0.971122     7.1
# 31       579                      Breka Bakery and Cafe    0.991203     6.9
# 32       260                                Tim Hortons    0.980282     6.5
# 33       892                      European Delicatessen    0.853162     6.7
# 34       220                                Yummy to Go    0.973014     5.8
# 35        46                                Morton Park    0.989532     NaN
# 36       727                               Blenz Coffee    0.977315     6.3
# 37       102             Beeryani Indian Bistro and Bar    0.920932     NaN
# 38       113                      Thai House Restaurant    0.263451     NaN
# 39       118                             Big Bang Sushi    0.464741     NaN
# 40       385                                 McDonald's    0.996580     5.8
# 41       217                               Sushi Aboard    0.950873     NaN
# 42       734      Chongqing Liuyishou HotPot Restaurant    0.956469     6.1
# 43       931                               Blenz Coffee    0.966290     6.2
# 44       424                  The Gazebo by English Bay    0.766852     NaN
# 45       428                             Gabriola House    0.912071     NaN
# 46       454                       Uno Brazilian Snacks    0.149805     NaN
# 47       527                              Habibi Donair    0.731716     NaN
# 48       600                             Holy Guacamole    0.885952     NaN
# 49       636                                 Cobs Bread    0.961159     NaN
#
#      latitude   longitude                     category
# 0   49.286660 -123.142780           Mexican Restaurant
# 1   49.286629 -123.142210                     Beer Bar
# 2   49.288425 -123.139849           Chinese Restaurant
# 3   49.284303 -123.143552                   Public Art
# 4   49.290643 -123.136956             Sushi Restaurant
# 5   49.286217 -123.140552                  Coffee Shop
# 6   49.286624 -123.133935                         Café
# 7   49.286418 -123.140245                         Café
# 8   49.290258 -123.133840             Ramen Restaurant
# 9   49.288276 -123.139917             Ice Cream Parlor
# 10  49.286922 -123.140937                          Pub
# 11  49.291740 -123.135346           Italian Restaurant
# 12  49.282285 -123.134538       Arts and Entertainment
# 13  49.287499 -123.128980             Ramen Restaurant
# 14  49.291333 -123.134825          Japanese Restaurant
# 15  49.290515 -123.133538             Ramen Restaurant
# 16  49.282095 -123.133548                   Restaurant
# 17  49.290752 -123.134045          Shanghai Restaurant
# 18  49.281570 -123.132773             Sushi Restaurant
# 19  49.287036 -123.141839                          Pub
# 20  49.290242 -123.137571                  Coffee Shop
# 21  49.281647 -123.132861                   Night Club
# 22  49.282224 -123.134289                         Café
# 23  49.287551 -123.129634                   Restaurant
# 24  49.281565 -123.133421                      Gay Bar
# 25  49.288600 -123.140107                     Pizzeria
# 26  49.282249 -123.133723      South Indian Restaurant
# 27  49.289640 -123.138493          American Restaurant
# 28  49.292295 -123.146508                      Brewery
# 29  49.291395 -123.129719                         Café
# 30  49.291374 -123.134990             Malay Restaurant
# 31  49.291338 -123.135961                         Café
# 32  49.289295 -123.139112  Cafe, Coffee, and Tea House
# 33  49.282028 -123.133948                         Deli
# 34  49.286439 -123.140328             Sushi Restaurant
# 35  49.287622 -123.141970                   Restaurant
# 36  49.289661 -123.132329                  Coffee Shop
# 37  49.287324 -123.141215            Indian Restaurant
# 38  49.288348 -123.140653              Thai Restaurant
# 39  49.288327 -123.140571             Sushi Restaurant
# 40  49.285281 -123.139012                 Burger Joint
# 41  49.288945 -123.139488             Sushi Restaurant
# 42  49.288997 -123.132110          Szechuan Restaurant
# 43  49.281941 -123.133372                         Café
# 44  49.284303 -123.140875                   Hookah Bar
# 45  49.284915 -123.138656  Historic and Protected Site
# 46  49.284704 -123.138476         Brazilian Restaurant
# 47  49.291029 -123.136502    Middle Eastern Restaurant
# 48  49.291524 -123.135814           Mexican Restaurant
# 49  49.290453 -123.134182                       Bakery

# %% [markdown]
# Testing the function:

# %%
test_outcome = search_foursquare(49.2827, -123.1207)
test_outcome
test_outcome.to_csv('data/foursquare_data_sample.csv', index=False)
# Out:
# Status code: 200
# Response text (first 300 chars): {"results":[{"categories":[{"id":13040,"name":"Dessert Shop","short_name":"Desserts","plural_name":"Dessert Shops","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/dessert_","suffix":".png"}},{"id":13148,"name":"French Restaurant","short_name":"French","plural_name":"French Restaurants"
# {
#     "results": [
#         {
#             "categories": [
#                 {
#                     "id": 13040,
#                     "name": "Dessert Shop",
#                     "short_name": "Desserts",
#                     "plural_name": "Dessert Shops",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/dessert_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13148,
#                     "name": "French Restaurant",
#                     "short_name": "French",
#                     "plural_name": "French Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/french_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 293,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.284766,
#                     "longitude": -123.122662
#                 },
#                 "roof": {
#                     "latitude": 49.284766,
#                     "longitude": -123.122662
#                 }
#             },
#             "name": "Thierry",
#             "popularity": 0.989182116159457,
#             "rating": 8.7
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13383,
#                     "name": "Steakhouse",
#                     "short_name": "Steakhouse",
#                     "plural_name": "Steakhouses",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/steakhouse_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13003,
#                     "name": "Bar",
#                     "short_name": "Bar",
#                     "plural_name": "Bars",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/nightlife/pub_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 324,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.283447,
#                     "longitude": -123.116466
#                 },
#                 "roof": {
#                     "latitude": 49.283447,
#                     "longitude": -123.116466
#                 }
#             },
#             "name": "The Keg Steakhouse + Bar",
#             "popularity": 0.9937165584878282,
#             "rating": 8.8
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13338,
#                     "name": "Seafood Restaurant",
#                     "short_name": "Seafood",
#                     "plural_name": "Seafood Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/seafood_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13383,
#                     "name": "Steakhouse",
#                     "short_name": "Steakhouse",
#                     "plural_name": "Steakhouses",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/steakhouse_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 372,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.284956,
#                     "longitude": -123.124545
#                 },
#                 "roof": {
#                     "latitude": 49.284956,
#                     "longitude": -123.124545
#                 }
#             },
#             "name": "Joe Fortes Seafood & Chop House",
#             "popularity": 0.9903869822638527,
#             "rating": 9.0
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13034,
#                     "name": "Caf\u00e9",
#                     "short_name": "Caf\u00e9",
#                     "plural_name": "Caf\u00e9s",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/cafe_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13302,
#                     "name": "Mediterranean Restaurant",
#                     "short_name": "Mediterranean",
#                     "plural_name": "Mediterranean Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/mediterranean_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 365,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.280498,
#                     "longitude": -123.116863
#                 },
#                 "roof": {
#                     "latitude": 49.280498,
#                     "longitude": -123.116863
#                 }
#             },
#             "name": "Cafe Medina",
#             "popularity": 0.9856452511433272,
#             "rating": 8.9
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13000,
#                     "name": "Dining and Drinking",
#                     "short_name": "Dining and Drinking",
#                     "plural_name": "Dining and Drinking",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/default_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 390,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.286052,
#                     "longitude": -123.122935
#                 },
#                 "roof": {
#                     "latitude": 49.286052,
#                     "longitude": -123.122935
#                 }
#             },
#             "name": "49th Parallel Caf\u00e9 & Lucky's Doughnuts - THURLOW",
#             "popularity": 0.9927578478241155,
#             "rating": 9.0
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13314,
#                     "name": "New American Restaurant",
#                     "short_name": "New American",
#                     "plural_name": "New American Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/newamerican_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13016,
#                     "name": "Lounge",
#                     "short_name": "Lounge",
#                     "plural_name": "Lounges",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/nightlife/default_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 203,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.282707,
#                     "longitude": -123.123298
#                 },
#                 "roof": {
#                     "latitude": 49.282707,
#                     "longitude": -123.123298
#                 }
#             },
#             "name": "JOEY Burrard",
#             "popularity": 0.9890136940158317,
#             "rating": 8.3
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13065,
#                     "name": "Restaurant",
#                     "short_name": "Restaurant",
#                     "plural_name": "Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/default_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13009,
#                     "name": "Cocktail Bar",
#                     "short_name": "Cocktail",
#                     "plural_name": "Cocktail Bars",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 143,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.283844,
#                     "longitude": -123.120961
#                 },
#                 "roof": {
#                     "latitude": 49.283844,
#                     "longitude": -123.120961
#                 }
#             },
#             "name": "Notch8 Restaurant",
#             "popularity": 0.9895837381942555,
#             "rating": 8.1
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13032,
#                     "name": "Cafe, Coffee, and Tea House",
#                     "short_name": "Cafe, Coffee, and Tea House",
#                     "plural_name": "Cafes, Coffee, and Tea Houses",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 128,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.283302,
#                     "longitude": -123.11938
#                 },
#                 "roof": {
#                     "latitude": 49.283334,
#                     "longitude": -123.119133
#                 }
#             },
#             "name": "Bel Cafe",
#             "popularity": 0.981603119696322,
#             "rating": 8.1
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13145,
#                     "name": "Fast Food Restaurant",
#                     "short_name": "Fast Food",
#                     "plural_name": "Fast Food Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/fastfood_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13265,
#                     "name": "Japanese Curry Restaurant",
#                     "short_name": "Japanese Curry",
#                     "plural_name": "Japanese Curry Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/default_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13383,
#                     "name": "Steakhouse",
#                     "short_name": "Steakhouse",
#                     "plural_name": "Steakhouses",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/steakhouse_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 272,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.280503,
#                     "longitude": -123.118891
#                 },
#                 "roof": {
#                     "latitude": 49.280503,
#                     "longitude": -123.118891
#                 }
#             },
#             "name": "ZAC ZAC Japanese Curry House",
#             "popularity": 0.9925764701309806,
#             "rating": 8.3
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13040,
#                     "name": "Dessert Shop",
#                     "short_name": "Desserts",
#                     "plural_name": "Dessert Shops",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/dessert_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13065,
#                     "name": "Restaurant",
#                     "short_name": "Restaurant",
#                     "plural_name": "Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/default_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 481,
#             "geocodes": {
#                 "drop_off": {
#                     "latitude": 49.278469,
#                     "longitude": -123.122214
#                 },
#                 "main": {
#                     "latitude": 49.278311,
#                     "longitude": -123.122111
#                 },
#                 "roof": {
#                     "latitude": 49.278311,
#                     "longitude": -123.122111
#                 }
#             },
#             "name": "Nero Belgian Waffle Bar",
#             "popularity": 0.9835075854742379,
#             "rating": 9.0
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13058,
#                     "name": "Hot Dog Joint",
#                     "short_name": "Hot Dogs",
#                     "plural_name": "Hot Dog Joints",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/hotdog_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13263,
#                     "name": "Japanese Restaurant",
#                     "short_name": "Japanese",
#                     "plural_name": "Japanese Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/japanese_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 322,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.280189,
#                     "longitude": -123.118297
#                 },
#                 "roof": {
#                     "latitude": 49.280189,
#                     "longitude": -123.118297
#                 }
#             },
#             "name": "Japadog",
#             "popularity": 0.9951675800329071,
#             "rating": 8.4
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13148,
#                     "name": "French Restaurant",
#                     "short_name": "French",
#                     "plural_name": "French Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/french_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13338,
#                     "name": "Seafood Restaurant",
#                     "short_name": "Seafood",
#                     "plural_name": "Seafood Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/seafood_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13383,
#                     "name": "Steakhouse",
#                     "short_name": "Steakhouse",
#                     "plural_name": "Steakhouses",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/steakhouse_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 214,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.283021,
#                     "longitude": -123.123893
#                 },
#                 "roof": {
#                     "latitude": 49.283021,
#                     "longitude": -123.123893
#                 }
#             },
#             "name": "Boulevard Kitchen & Oyster Bar",
#             "popularity": 0.9923562257893168,
#             "rating": 8.1
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13068,
#                     "name": "American Restaurant",
#                     "short_name": "American",
#                     "plural_name": "American Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/default_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13303,
#                     "name": "Mexican Restaurant",
#                     "short_name": "Mexican",
#                     "plural_name": "Mexican Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/mexican_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13383,
#                     "name": "Steakhouse",
#                     "short_name": "Steakhouse",
#                     "plural_name": "Steakhouses",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/steakhouse_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 349,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.285532,
#                     "longitude": -123.118834
#                 },
#                 "roof": {
#                     "latitude": 49.285532,
#                     "longitude": -123.118834
#                 }
#             },
#             "name": "Cactus Club Cafe Bentall 5",
#             "popularity": 0.996229935092697,
#             "rating": 8.3
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13035,
#                     "name": "Coffee Shop",
#                     "short_name": "Coffee Shop",
#                     "plural_name": "Coffee Shops",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 384,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.279891,
#                     "longitude": -123.123788
#                 },
#                 "roof": {
#                     "latitude": 49.279891,
#                     "longitude": -123.123788
#                 }
#             },
#             "name": "Pallet Coffee Roasters",
#             "popularity": 0.9884306942878982,
#             "rating": 8.4
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13338,
#                     "name": "Seafood Restaurant",
#                     "short_name": "Seafood",
#                     "plural_name": "Seafood Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/seafood_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 644,
#             "geocodes": {
#                 "drop_off": {
#                     "latitude": 49.278661,
#                     "longitude": -123.114253
#                 },
#                 "main": {
#                     "latitude": 49.278557,
#                     "longitude": -123.114183
#                 },
#                 "roof": {
#                     "latitude": 49.278557,
#                     "longitude": -123.114183
#                 }
#             },
#             "name": "Fanny Bay Oyster Bar & Shellfish Market",
#             "popularity": 0.9881068055501574,
#             "rating": 9.1
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13002,
#                     "name": "Bakery",
#                     "short_name": "Bakery",
#                     "plural_name": "Bakeries",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/bakery_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13034,
#                     "name": "Caf\u00e9",
#                     "short_name": "Caf\u00e9",
#                     "plural_name": "Caf\u00e9s",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/cafe_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13065,
#                     "name": "Restaurant",
#                     "short_name": "Restaurant",
#                     "plural_name": "Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/default_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 584,
#             "geocodes": {
#                 "drop_off": {
#                     "latitude": 49.285854,
#                     "longitude": -123.127187
#                 },
#                 "main": {
#                     "latitude": 49.285765,
#                     "longitude": -123.127128
#                 },
#                 "roof": {
#                     "latitude": 49.285765,
#                     "longitude": -123.127128
#                 }
#             },
#             "name": "Breka Bakery & Cafe",
#             "popularity": 0.996968401414746,
#             "rating": 8.7
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13065,
#                     "name": "Restaurant",
#                     "short_name": "Restaurant",
#                     "plural_name": "Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/default_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13016,
#                     "name": "Lounge",
#                     "short_name": "Lounge",
#                     "plural_name": "Lounges",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/nightlife/default_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 240,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.281585,
#                     "longitude": -123.123689
#                 },
#                 "roof": {
#                     "latitude": 49.281585,
#                     "longitude": -123.123689
#                 }
#             },
#             "name": "Earls",
#             "popularity": 0.9896873825903326,
#             "rating": 7.9
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13272,
#                     "name": "Ramen Restaurant",
#                     "short_name": "Ramen",
#                     "plural_name": "Ramen Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/ramen_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13377,
#                     "name": "Vegan and Vegetarian Restaurant",
#                     "short_name": "Vegan and Vegetarian Restaurant",
#                     "plural_name": "Vegan and Vegetarian Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/vegetarian_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 332,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.280369,
#                     "longitude": -123.117907
#                 },
#                 "roof": {
#                     "latitude": 49.280369,
#                     "longitude": -123.117907
#                 }
#             },
#             "name": "JINYA Ramen Bar - Vancouver Downtown",
#             "popularity": 0.9864873618614534,
#             "rating": 8.1
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13018,
#                     "name": "Pub",
#                     "short_name": "Pub",
#                     "plural_name": "Pubs",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/nightlife/pub_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13065,
#                     "name": "Restaurant",
#                     "short_name": "Restaurant",
#                     "plural_name": "Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/default_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 296,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.280066,
#                     "longitude": -123.121369
#                 },
#                 "roof": {
#                     "latitude": 49.280066,
#                     "longitude": -123.121369
#                 }
#             },
#             "name": "Dublin Calling",
#             "popularity": 0.9931335587598948,
#             "rating": 8.0
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13002,
#                     "name": "Bakery",
#                     "short_name": "Bakery",
#                     "plural_name": "Bakeries",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/bakery_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 528,
#             "geocodes": {
#                 "drop_off": {
#                     "latitude": 49.285888,
#                     "longitude": -123.114773
#                 },
#                 "main": {
#                     "latitude": 49.285619,
#                     "longitude": -123.114947
#                 },
#                 "roof": {
#                     "latitude": 49.285619,
#                     "longitude": -123.114947
#                 }
#             },
#             "name": "Breka Bakery & Caf\u00e9",
#             "popularity": 0.9975384455931698,
#             "rating": 8.4
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13065,
#                     "name": "Restaurant",
#                     "short_name": "Restaurant",
#                     "plural_name": "Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/default_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 19014,
#                     "name": "Hotel",
#                     "short_name": "Hotel",
#                     "plural_name": "Hotels",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/travel/hotel_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 710,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.287101,
#                     "longitude": -123.113775
#                 },
#                 "roof": {
#                     "latitude": 49.287101,
#                     "longitude": -123.113775
#                 }
#             },
#             "name": "Fairmont Waterfront",
#             "popularity": 0.9960615129490717,
#             "rating": 8.9
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13064,
#                     "name": "Pizzeria",
#                     "short_name": "Pizza",
#                     "plural_name": "Pizzerias",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/pizza_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13236,
#                     "name": "Italian Restaurant",
#                     "short_name": "Italian",
#                     "plural_name": "Italian Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/italian_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 664,
#             "geocodes": {
#                 "drop_off": {
#                     "latitude": 49.276597,
#                     "longitude": -123.120073
#                 },
#                 "main": {
#                     "latitude": 49.276782,
#                     "longitude": -123.120196
#                 },
#                 "roof": {
#                     "latitude": 49.276782,
#                     "longitude": -123.120196
#                 }
#             },
#             "name": "The Parlour",
#             "popularity": 0.9807350978791766,
#             "rating": 8.7
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13276,
#                     "name": "Sushi Restaurant",
#                     "short_name": "Sushi",
#                     "plural_name": "Sushi Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/sushi_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 769,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.286766,
#                     "longitude": -123.112205
#                 },
#                 "roof": {
#                     "latitude": 49.286766,
#                     "longitude": -123.112205
#                 }
#             },
#             "name": "Miku",
#             "popularity": 0.9939886250275305,
#             "rating": 9.0
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13035,
#                     "name": "Coffee Shop",
#                     "short_name": "Coffee Shop",
#                     "plural_name": "Coffee Shops",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13065,
#                     "name": "Restaurant",
#                     "short_name": "Restaurant",
#                     "plural_name": "Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/default_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 767,
#             "geocodes": {
#                 "drop_off": {
#                     "latitude": 49.282906,
#                     "longitude": -123.110167
#                 },
#                 "main": {
#                     "latitude": 49.282787,
#                     "longitude": -123.110244
#                 },
#                 "roof": {
#                     "latitude": 49.282787,
#                     "longitude": -123.110244
#                 }
#             },
#             "name": "Nemesis Coffee",
#             "popularity": 0.9855286511977406,
#             "rating": 9.0
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13034,
#                     "name": "Caf\u00e9",
#                     "short_name": "Caf\u00e9",
#                     "plural_name": "Caf\u00e9s",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/cafe_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13035,
#                     "name": "Coffee Shop",
#                     "short_name": "Coffee Shop",
#                     "plural_name": "Coffee Shops",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13065,
#                     "name": "Restaurant",
#                     "short_name": "Restaurant",
#                     "plural_name": "Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/default_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 829,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.283261,
#                     "longitude": -123.109473
#                 },
#                 "roof": {
#                     "latitude": 49.283261,
#                     "longitude": -123.109473
#                 }
#             },
#             "name": "Revolver",
#             "popularity": 0.9838832964100173,
#             "rating": 9.3
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13272,
#                     "name": "Ramen Restaurant",
#                     "short_name": "Ramen",
#                     "plural_name": "Ramen Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/ramen_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 798,
#             "geocodes": {
#                 "drop_off": {
#                     "latitude": 49.287359,
#                     "longitude": -123.129071
#                 },
#                 "main": {
#                     "latitude": 49.287499,
#                     "longitude": -123.12898
#                 },
#                 "roof": {
#                     "latitude": 49.287499,
#                     "longitude": -123.12898
#                 }
#             },
#             "name": "Ramen Danbo - Robson",
#             "popularity": 0.9960226463005428,
#             "rating": 9.0
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13314,
#                     "name": "New American Restaurant",
#                     "short_name": "New American",
#                     "plural_name": "New American Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/newamerican_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 424,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.286469,
#                     "longitude": -123.118589
#                 },
#                 "roof": {
#                     "latitude": 49.286469,
#                     "longitude": -123.118589
#                 }
#             },
#             "name": "JOEY Bentall One",
#             "popularity": 0.9964501794343608,
#             "rating": 8.1
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13046,
#                     "name": "Ice Cream Parlor",
#                     "short_name": "Ice Cream",
#                     "plural_name": "Ice Cream Parlors",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/icecream_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13065,
#                     "name": "Restaurant",
#                     "short_name": "Restaurant",
#                     "plural_name": "Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/default_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 849,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.275114,
#                     "longitude": -123.121514
#                 },
#                 "roof": {
#                     "latitude": 49.275114,
#                     "longitude": -123.121514
#                 }
#             },
#             "name": "Mister",
#             "popularity": 0.9777812325909804,
#             "rating": 9.1
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13077,
#                     "name": "Belgian Restaurant",
#                     "short_name": "Belgian",
#                     "plural_name": "Belgian Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/default_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 829,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.280213,
#                     "longitude": -123.1097
#                 },
#                 "roof": {
#                     "latitude": 49.280213,
#                     "longitude": -123.1097
#                 }
#             },
#             "name": "Chambar",
#             "popularity": 0.9941311360721365,
#             "rating": 8.9
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13068,
#                     "name": "American Restaurant",
#                     "short_name": "American",
#                     "plural_name": "American Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/default_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13303,
#                     "name": "Mexican Restaurant",
#                     "short_name": "Mexican",
#                     "plural_name": "Mexican Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/mexican_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 783,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.289603,
#                     "longitude": -123.118045
#                 },
#                 "roof": {
#                     "latitude": 49.289603,
#                     "longitude": -123.118045
#                 }
#             },
#             "name": "Cactus Club Cafe",
#             "popularity": 0.9980696231230648,
#             "rating": 8.8
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13003,
#                     "name": "Bar",
#                     "short_name": "Bar",
#                     "plural_name": "Bars",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/nightlife/pub_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13057,
#                     "name": "Gastropub",
#                     "short_name": "Gastropub",
#                     "plural_name": "Gastropubs",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/gastropub_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13064,
#                     "name": "Pizzeria",
#                     "short_name": "Pizza",
#                     "plural_name": "Pizzerias",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/pizza_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 824,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.289881,
#                     "longitude": -123.116933
#                 },
#                 "roof": {
#                     "latitude": 49.289881,
#                     "longitude": -123.116933
#                 }
#             },
#             "name": "Tap & Barrel",
#             "popularity": 0.9943513804138002,
#             "rating": 8.8
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13003,
#                     "name": "Bar",
#                     "short_name": "Bar",
#                     "plural_name": "Bars",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/nightlife/pub_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13065,
#                     "name": "Restaurant",
#                     "short_name": "Restaurant",
#                     "plural_name": "Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/default_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 722,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.284949,
#                     "longitude": -123.110915
#                 },
#                 "roof": {
#                     "latitude": 49.284949,
#                     "longitude": -123.110915
#                 }
#             },
#             "name": "Steamworks Brewing Co",
#             "popularity": 0.9990283337867776,
#             "rating": 8.6
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13002,
#                     "name": "Bakery",
#                     "short_name": "Bakery",
#                     "plural_name": "Bakeries",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/bakery_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13034,
#                     "name": "Caf\u00e9",
#                     "short_name": "Caf\u00e9",
#                     "plural_name": "Caf\u00e9s",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/cafe_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13040,
#                     "name": "Dessert Shop",
#                     "short_name": "Desserts",
#                     "plural_name": "Dessert Shops",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/dessert_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 709,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.278414,
#                     "longitude": -123.12788
#                 },
#                 "roof": {
#                     "latitude": 49.278414,
#                     "longitude": -123.12788
#                 }
#             },
#             "name": "Breka Bakery & Cafe",
#             "popularity": 0.9941181805226269,
#             "rating": 8.5
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13065,
#                     "name": "Restaurant",
#                     "short_name": "Restaurant",
#                     "plural_name": "Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/default_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13016,
#                     "name": "Lounge",
#                     "short_name": "Lounge",
#                     "plural_name": "Lounges",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/nightlife/default_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 912,
#             "geocodes": {
#                 "drop_off": {
#                     "latitude": 49.284241,
#                     "longitude": -123.108384
#                 },
#                 "main": {
#                     "latitude": 49.284105,
#                     "longitude": -123.108409
#                 },
#                 "roof": {
#                     "latitude": 49.284105,
#                     "longitude": -123.108409
#                 }
#             },
#             "name": "Pourhouse Restaurant",
#             "popularity": 0.978675165507145,
#             "rating": 9.0
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13057,
#                     "name": "Gastropub",
#                     "short_name": "Gastropub",
#                     "plural_name": "Gastropubs",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/gastropub_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13018,
#                     "name": "Pub",
#                     "short_name": "Pub",
#                     "plural_name": "Pubs",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/nightlife/pub_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 387,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.279552,
#                     "longitude": -123.122866
#                 },
#                 "roof": {
#                     "latitude": 49.279552,
#                     "longitude": -123.122866
#                 }
#             },
#             "name": "The Famous Warehouse",
#             "popularity": 0.9939497583790017,
#             "rating": 7.9
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13049,
#                     "name": "Diner",
#                     "short_name": "Diner",
#                     "plural_name": "Diners",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/diner_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13068,
#                     "name": "American Restaurant",
#                     "short_name": "American",
#                     "plural_name": "American Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/default_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 219,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.28388,
#                     "longitude": -123.118206
#                 },
#                 "roof": {
#                     "latitude": 49.28388,
#                     "longitude": -123.118206
#                 }
#             },
#             "name": "Diva at the Met",
#             "popularity": 0.9898169380854289,
#             "rating": 7.6
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13148,
#                     "name": "French Restaurant",
#                     "short_name": "French",
#                     "plural_name": "French Restaurants",
#                     "icon": {
# ...
#                 }
#             },
#             "name": "Tableau Bar Bistro",
#             "popularity": 0.9885213831344657,
#             "rating": 8.2
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13276,
#                     "name": "Sushi Restaurant",
#                     "short_name": "Sushi",
#                     "plural_name": "Sushi Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/sushi_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 520,
#             "geocodes": {
#                 "drop_off": {
#                     "latitude": 49.285547,
#                     "longitude": -123.126281
#                 },
#                 "main": {
#                     "latitude": 49.285744,
#                     "longitude": -123.126153
#                 },
#                 "roof": {
#                     "latitude": 49.285744,
#                     "longitude": -123.126153
#                 }
#             },
#             "name": "Hello Nori",
#             "popularity": 0.9795690984233096,
#             "rating": 8.0
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13068,
#                     "name": "American Restaurant",
#                     "short_name": "American",
#                     "plural_name": "American Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/default_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 566,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.285939,
#                     "longitude": -123.126494
#                 },
#                 "roof": {
#                     "latitude": 49.285939,
#                     "longitude": -123.126494
#                 }
#             },
#             "name": "Earl's Restaurant",
#             "popularity": 0.9852954513065671,
#             "rating": 8.1
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13383,
#                     "name": "Steakhouse",
#                     "short_name": "Steakhouse",
#                     "plural_name": "Steakhouses",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/steakhouse_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13003,
#                     "name": "Bar",
#                     "short_name": "Bar",
#                     "plural_name": "Bars",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/nightlife/pub_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 681,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.27671,
#                     "longitude": -123.11946
#                 },
#                 "roof": {
#                     "latitude": 49.27671,
#                     "longitude": -123.11946
#                 }
#             },
#             "name": "The Keg Steakhouse + Bar",
#             "popularity": 0.9859432287820488,
#             "rating": 8.2
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13065,
#                     "name": "Restaurant",
#                     "short_name": "Restaurant",
#                     "plural_name": "Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/default_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13145,
#                     "name": "Fast Food Restaurant",
#                     "short_name": "Fast Food",
#                     "plural_name": "Fast Food Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/fastfood_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 940,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.282095,
#                     "longitude": -123.133548
#                 },
#                 "roof": {
#                     "latitude": 49.282095,
#                     "longitude": -123.133548
#                 }
#             },
#             "name": "La Belle Patate",
#             "popularity": 0.9857100288908754,
#             "rating": 8.6
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13018,
#                     "name": "Pub",
#                     "short_name": "Pub",
#                     "plural_name": "Pubs",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/nightlife/pub_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 790,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.276963,
#                     "longitude": -123.126944
#                 },
#                 "roof": {
#                     "latitude": 49.276963,
#                     "longitude": -123.126944
#                 }
#             },
#             "name": "Morrissey Irish Bar & Restaurant",
#             "popularity": 0.9857488955394043,
#             "rating": 8.3
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13145,
#                     "name": "Fast Food Restaurant",
#                     "short_name": "Fast Food",
#                     "plural_name": "Fast Food Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/fastfood_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 727,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.277256,
#                     "longitude": -123.126564
#                 },
#                 "roof": {
#                     "latitude": 49.277256,
#                     "longitude": -123.126564
#                 }
#             },
#             "name": "Fritz European Fry House",
#             "popularity": 0.9913845595760944,
#             "rating": 8.2
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13032,
#                     "name": "Cafe, Coffee, and Tea House",
#                     "short_name": "Cafe, Coffee, and Tea House",
#                     "plural_name": "Cafes, Coffee, and Tea Houses",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13043,
#                     "name": "Donut Shop",
#                     "short_name": "Donuts",
#                     "plural_name": "Donut Shops",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/donuts_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13065,
#                     "name": "Restaurant",
#                     "short_name": "Restaurant",
#                     "plural_name": "Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/default_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 478,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.28599,
#                     "longitude": -123.116439
#                 },
#                 "roof": {
#                     "latitude": 49.28599,
#                     "longitude": -123.116439
#                 }
#             },
#             "name": "Tim Hortons",
#             "popularity": 0.9742443675748507,
#             "rating": 7.8
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13035,
#                     "name": "Coffee Shop",
#                     "short_name": "Coffee Shop",
#                     "plural_name": "Coffee Shops",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13145,
#                     "name": "Fast Food Restaurant",
#                     "short_name": "Fast Food",
#                     "plural_name": "Fast Food Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/fastfood_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13334,
#                     "name": "Sandwich Spot",
#                     "short_name": "Sandwich Spot",
#                     "plural_name": "Sandwich Spots",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/deli_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 545,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.287715,
#                     "longitude": -123.12048
#                 },
#                 "roof": {
#                     "latitude": 49.287715,
#                     "longitude": -123.12048
#                 }
#             },
#             "name": "Caffe Artigiano",
#             "popularity": 0.9577908196976175,
#             "rating": 7.9
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13377,
#                     "name": "Vegan and Vegetarian Restaurant",
#                     "short_name": "Vegan and Vegetarian Restaurant",
#                     "plural_name": "Vegan and Vegetarian Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/vegetarian_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 858,
#             "geocodes": {
#                 "drop_off": {
#                     "latitude": 49.274874,
#                     "longitude": -123.121659
#                 },
#                 "main": {
#                     "latitude": 49.275006,
#                     "longitude": -123.121748
#                 },
#                 "roof": {
#                     "latitude": 49.275006,
#                     "longitude": -123.121748
#                 }
#             },
#             "name": "MeeT in Yaletown",
#             "popularity": 0.978921320947828,
#             "rating": 8.3
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13028,
#                     "name": "Breakfast Spot",
#                     "short_name": "Breakfast",
#                     "plural_name": "Breakfast Spots",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/breakfast_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 568,
#             "geocodes": {
#                 "drop_off": {
#                     "latitude": 49.286416,
#                     "longitude": -123.115589
#                 },
#                 "main": {
#                     "latitude": 49.286535,
#                     "longitude": -123.115512
#                 },
#                 "roof": {
#                     "latitude": 49.286535,
#                     "longitude": -123.115512
#                 }
#             },
#             "name": "Palate Kitchen",
#             "popularity": 0.9850363403163745,
#             "rating": 7.8
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13034,
#                     "name": "Caf\u00e9",
#                     "short_name": "Caf\u00e9",
#                     "plural_name": "Caf\u00e9s",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/cafe_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13145,
#                     "name": "Fast Food Restaurant",
#                     "short_name": "Fast Food",
#                     "plural_name": "Fast Food Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/fastfood_",
#                         "suffix": ".png"
#                     }
#                 },
#                 {
#                     "id": 13236,
#                     "name": "Italian Restaurant",
#                     "short_name": "Italian",
#                     "plural_name": "Italian Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/italian_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 625,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.288095,
#                     "longitude": -123.117105
#                 },
#                 "roof": {
#                     "latitude": 49.288095,
#                     "longitude": -123.117105
#                 }
#             },
#             "name": "Giovane Cafe + Eatery + Market",
#             "popularity": 0.9824322748649384,
#             "rating": 7.8
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13028,
#                     "name": "Breakfast Spot",
#                     "short_name": "Breakfast",
#                     "plural_name": "Breakfast Spots",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/breakfast_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 867,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.290087,
#                     "longitude": -123.11687
#                 },
#                 "roof": {
#                     "latitude": 49.290087,
#                     "longitude": -123.11687
#                 }
#             },
#             "name": "De Dutch Vancouver Convention Centre",
#             "popularity": 0.9873424281290891,
#             "rating": 8.1
#         },
#         {
#             "categories": [
#                 {
#                     "id": 13298,
#                     "name": "Lebanese Restaurant",
#                     "short_name": "Lebanese",
#                     "plural_name": "Lebanese Restaurants",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/middleeastern_",
#                         "suffix": ".png"
#                     }
#                 }
#             ],
#             "distance": 407,
#             "geocodes": {
#                 "main": {
#                     "latitude": 49.28443,
#                     "longitude": -123.115738
#                 },
#                 "roof": {
#                     "latitude": 49.28443,
#                     "longitude": -123.115738
#                 }
#             },
#             "name": "Zaatar W Zeit",
#             "popularity": 0.9931076476608756,
#             "rating": 7.5
#         }
#     ],
#     "context": {
#         "geo_bounds": {
#             "circle": {
#                 "center": {
#                     "latitude": 49.2827,
#                     "longitude": -123.1207
#                 },
#                 "radius": 1000
#             }
#         }
#     }
# }

# %%
test_outcome.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   distance    50 non-null     int64
#  1   name        50 non-null     object
#  2   popularity  50 non-null     float64
#  3   rating      50 non-null     float64
#  4   latitude    50 non-null     float64
#  5   longitude   50 non-null     float64
#  6   category    50 non-null     object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 2.9+ KB

# %%
yelp_api_key = os.environ["YELP_API_KEY"]

def search_yelp(lat, lon, categories='transport,bars,restaurants,coffeeshops', radius=1000, limit=50):
    """
    Queries Yelp Fusion API for businesses near a given lat/lon.
    Default search term is 'restaurants'.
    """
    url = "https://api.yelp.com/v3/businesses/search"
    headers = {
        "Authorization": f"Bearer {yelp_api_key}"
    }
    params = {
        "latitude": lat,
        "longitude": lon,
        "radius": radius,
        "limit": limit,
        "categories": categories
    }

    response = requests.get(url, headers=headers, params=params)

    print("Status code:", response.status_code)
    print("Response text (first 300 chars):", response.text[:300])

    if response.status_code != 200:
        print(f"Error: {response.status_code} — {response.text}")
        return None

    data = response.json()
    print(json.dumps(data, indent=4))

    businesses = data.get("businesses", [])

    final_businesses = []
    for b in businesses:
        final_businesses.append({
            'distance': round(b.get('distance', 0)),
            'name': b.get('name'),
            'rating': b.get('rating'),
            'review_count': b.get('review_count'),
            'latitude': b.get('coordinates', {}).get('latitude'),
            'longitude': b.get('coordinates', {}).get('longitude'),
            'category': b.get('categories', [{}])[0].get('title') if b.get('categories') else None
        })

    df = pd.DataFrame(final_businesses)
    return df

# %%
yelp_df = search_yelp(49.2827, -123.1207)
yelp_df
yelp_df.to_csv('data/yelp_data.csv', index=False)
# Out:
# Status code: 200
# Response text (first 300 chars): {"businesses": [{"id": "70D_rxm388HaD2qMTB59xw", "alias": "hawksworth-restaurant-vancouver-3", "name": "Hawksworth Restaurant", "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/60cqdD_4cxAwkWMRObjnZQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/hawksworth-restaurant-vancouver-3?
# {
#     "businesses": [
#         {
#             "id": "70D_rxm388HaD2qMTB59xw",
#             "alias": "hawksworth-restaurant-vancouver-3",
#             "name": "Hawksworth Restaurant",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/60cqdD_4cxAwkWMRObjnZQ/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/hawksworth-restaurant-vancouver-3?adjust_creative=7NCke8zvVGD8HWvkWm6oXw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7NCke8zvVGD8HWvkWm6oXw",
#             "review_count": 713,
#             "categories": [
#                 {
#                     "alias": "newcanadian",
#                     "title": "Canadian (New)"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 49.2833971,
#                 "longitude": -123.1191704
#             },
#             "transactions": [],
#             "price": "$$$",
#             "location": {
#                 "address1": "801 W Georgia Street",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Vancouver",
#                 "zip_code": "V6C 1P7",
#                 "country": "CA",
#                 "state": "BC",
#                 "display_address": [
#                     "801 W Georgia Street",
#                     "Vancouver, BC V6C 1P7",
#                     "Canada"
#                 ]
#             },
#             "phone": "+16046737000",
#             "display_phone": "+1 604-673-7000",
#             "distance": 135.34462327081718,
#             "business_hours": [
#                 {
#                     "open": [
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "2200",
#                             "day": 0
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "2200",
#                             "day": 1
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "2200",
#                             "day": 2
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "2200",
#                             "day": 3
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "2300",
#                             "day": 4
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1500",
#                             "end": "2300",
#                             "day": 5
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1500",
#                             "end": "2200",
#                             "day": 6
#                         }
#                     ],
#                     "hours_type": "REGULAR",
#                     "is_open_now": true
#                 }
#             ],
#             "attributes": {
#                 "business_temp_closed": null,
#                 "menu_url": "https://hawksworthrestaurant.com/wp-content/uploads/2023/02/Lunch-DOV-2023.pdf",
#                 "open24_hours": null,
#                 "waitlist_reservation": null
#             }
#         },
#         {
#             "id": "DJplkq9x17wm2V4vIT4brg",
#             "alias": "boulevard-vancouver-2",
#             "name": "Boulevard",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/-UzMby54GjRv6Qp1uVCfNQ/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/boulevard-vancouver-2?adjust_creative=7NCke8zvVGD8HWvkWm6oXw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7NCke8zvVGD8HWvkWm6oXw",
#             "review_count": 317,
#             "categories": [
#                 {
#                     "alias": "seafood",
#                     "title": "Seafood"
#                 },
#                 {
#                     "alias": "lounges",
#                     "title": "Lounges"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 49.2827182,
#                 "longitude": -123.123884
#             },
#             "transactions": [],
#             "price": "$$$",
#             "location": {
#                 "address1": "845 Burrard Street",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Vancouver",
#                 "zip_code": "V6Z 2K7",
#                 "country": "CA",
#                 "state": "BC",
#                 "display_address": [
#                     "845 Burrard Street",
#                     "Vancouver, BC V6Z 2K7",
#                     "Canada"
#                 ]
#             },
#             "phone": "+16046422900",
#             "display_phone": "+1 604-642-2900",
#             "distance": 230.96155124733087,
#             "business_hours": [
#                 {
#                     "open": [
#                         {
#                             "is_overnight": false,
#                             "start": "0630",
#                             "end": "1100",
#                             "day": 0
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1500",
#                             "end": "2200",
#                             "day": 0
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "0630",
#                             "end": "1100",
#                             "day": 1
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1500",
#                             "end": "2200",
#                             "day": 1
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "0630",
#                             "end": "1100",
#                             "day": 2
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1500",
#                             "end": "2200",
#                             "day": 2
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "0630",
#                             "end": "1100",
#                             "day": 3
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1500",
#                             "end": "2200",
#                             "day": 3
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "0630",
#                             "end": "1100",
#                             "day": 4
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1500",
#                             "end": "2200",
#                             "day": 4
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "0630",
#                             "end": "1100",
#                             "day": 5
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1500",
#                             "end": "2200",
#                             "day": 5
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "0630",
#                             "end": "1100",
#                             "day": 6
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1500",
#                             "end": "2200",
#                             "day": 6
#                         }
#                     ],
#                     "hours_type": "REGULAR",
#                     "is_open_now": true
#                 }
#             ],
#             "attributes": {
#                 "business_temp_closed": null,
#                 "menu_url": "http://boulevardvancouver.ca/menu/core",
#                 "open24_hours": null,
#                 "waitlist_reservation": null
#             }
#         },
#         {
#             "id": "S-wgeQmV5v4g4wti05zUlQ",
#             "alias": "tendon-kohaku-vancouver",
#             "name": "Tendon Kohaku",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/nNxAAueRGJSspcQxCq0cSw/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/tendon-kohaku-vancouver?adjust_creative=7NCke8zvVGD8HWvkWm6oXw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7NCke8zvVGD8HWvkWm6oXw",
#             "review_count": 186,
#             "categories": [
#                 {
#                     "alias": "japanese",
#                     "title": "Japanese"
#                 }
#             ],
#             "rating": 4.3,
#             "coordinates": {
#                 "latitude": 49.28107123873706,
#                 "longitude": -123.12179426645872
#             },
#             "transactions": [],
#             "price": "$$",
#             "location": {
#                 "address1": "840 Howe Street",
#                 "address2": "Suite 190",
#                 "address3": null,
#                 "city": "Vancouver",
#                 "zip_code": "V6Z 2S9",
#                 "country": "CA",
#                 "state": "BC",
#                 "display_address": [
#                     "840 Howe Street",
#                     "Suite 190",
#                     "Vancouver, BC V6Z 2S9",
#                     "Canada"
#                 ]
#             },
#             "phone": "+16044163936",
#             "display_phone": "+1 604-416-3936",
#             "distance": 197.73984464305272,
#             "business_hours": [
#                 {
#                     "open": [
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "2200",
#                             "day": 0
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "2200",
#                             "day": 1
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "2200",
#                             "day": 2
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "2200",
#                             "day": 3
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "2200",
#                             "day": 4
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "2200",
#                             "day": 5
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "2200",
#                             "day": 6
#                         }
#                     ],
#                     "hours_type": "REGULAR",
#                     "is_open_now": true
#                 }
#             ],
#             "attributes": {
#                 "business_temp_closed": null,
#                 "menu_url": "http://www.kohakutendon.com/menu/",
#                 "open24_hours": null,
#                 "waitlist_reservation": null
#             }
#         },
#         {
#             "id": "g-WSOodoG-L81DFYWM0FMQ",
#             "alias": "italian-kitchen-vancouver",
#             "name": "Italian Kitchen",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/YykccpHAnwuI7ti53N3bdg/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/italian-kitchen-vancouver?adjust_creative=7NCke8zvVGD8HWvkWm6oXw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7NCke8zvVGD8HWvkWm6oXw",
#             "review_count": 731,
#             "categories": [
#                 {
#                     "alias": "italian",
#                     "title": "Italian"
#                 }
#             ],
#             "rating": 3.8,
#             "coordinates": {
#                 "latitude": 49.2825685,
#                 "longitude": -123.1236112
#             },
#             "transactions": [],
#             "price": "$$$",
#             "location": {
#                 "address1": "860 Burrard St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Vancouver",
#                 "zip_code": "V6Z 1X9",
#                 "country": "CA",
#                 "state": "BC",
#                 "display_address": [
#                     "860 Burrard St",
#                     "Vancouver, BC V6Z 1X9",
#                     "Canada"
#                 ]
#             },
#             "phone": "+16046872858",
#             "display_phone": "+1 604-687-2858",
#             "distance": 211.67099851683588,
#             "business_hours": [
#                 {
#                     "open": [
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "2200",
#                             "day": 0
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "2300",
#                             "day": 1
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "2300",
#                             "day": 2
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "2300",
#                             "day": 3
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "0000",
#                             "day": 4
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1100",
#                             "end": "0000",
#                             "day": 5
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1100",
#                             "end": "2200",
#                             "day": 6
#                         }
#                     ],
#                     "hours_type": "REGULAR",
#                     "is_open_now": true
#                 }
#             ],
#             "attributes": {
#                 "business_temp_closed": null,
#                 "menu_url": null,
#                 "open24_hours": null,
#                 "waitlist_reservation": null
#             }
#         },
#         {
#             "id": "nV-MkqGnkH1fyxuVCs5Jpw",
#             "alias": "joey-burrard-vancouver-4",
#             "name": "JOEY Burrard",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/zjq_yZMCNQ7QjBq_yNG7MQ/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/joey-burrard-vancouver-4?adjust_creative=7NCke8zvVGD8HWvkWm6oXw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7NCke8zvVGD8HWvkWm6oXw",
#             "review_count": 651,
#             "categories": [
#                 {
#                     "alias": "newcanadian",
#                     "title": "Canadian (New)"
#                 },
#                 {
#                     "alias": "lounges",
#                     "title": "Lounges"
#                 },
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 }
#             ],
#             "rating": 4.1,
#             "coordinates": {
#                 "latitude": 49.282606,
#                 "longitude": -123.1231879
#             },
#             "transactions": [],
#             "price": "$$",
#             "location": {
#                 "address1": "820 Burrard St",
#                 "address2": "Vancouver",
#                 "address3": "",
#                 "city": "Vancouver",
#                 "zip_code": "V6Z 1X9",
#                 "country": "CA",
#                 "state": "BC",
#                 "display_address": [
#                     "820 Burrard St",
#                     "Vancouver",
#                     "Vancouver, BC V6Z 1X9",
#                     "Canada"
#                 ]
#             },
#             "phone": "+16046835639",
#             "display_phone": "+1 604-683-5639",
#             "distance": 180.7634502412609,
#             "business_hours": [
#                 {
#                     "open": [
#                         {
#                             "is_overnight": true,
#                             "start": "1100",
#                             "end": "0100",
#                             "day": 0
#                         },
#                         {
#                             "is_overnight": true,
#                             "start": "1100",
#                             "end": "0100",
#                             "day": 1
#                         },
#                         {
#                             "is_overnight": true,
#                             "start": "1100",
#                             "end": "0100",
#                             "day": 2
#                         },
#                         {
#                             "is_overnight": true,
#                             "start": "1100",
#                             "end": "0100",
#                             "day": 3
#                         },
#                         {
#                             "is_overnight": true,
#                             "start": "1100",
#                             "end": "0200",
#                             "day": 4
#                         },
#                         {
#                             "is_overnight": true,
#                             "start": "1100",
#                             "end": "0200",
#                             "day": 5
#                         },
#                         {
#                             "is_overnight": true,
#                             "start": "1100",
#                             "end": "0100",
#                             "day": 6
#                         }
#                     ],
#                     "hours_type": "REGULAR",
#                     "is_open_now": true
#                 }
#             ],
#             "attributes": {
#                 "business_temp_closed": null,
#                 "menu_url": "https://joeyrestaurants.com/location/joey-burrard/menu#food",
#                 "open24_hours": null,
#                 "waitlist_reservation": null
#             }
#         },
#         {
#             "id": "2vXKCM4qvVhCiYuCjOSMEw",
#             "alias": "bacchus-restaurant-and-lounge-vancouver",
#             "name": "Bacchus Restaurant & Lounge",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/pjNggt8wuzmZhKS-Lmgw9Q/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/bacchus-restaurant-and-lounge-vancouver?adjust_creative=7NCke8zvVGD8HWvkWm6oXw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7NCke8zvVGD8HWvkWm6oXw",
#             "review_count": 216,
#             "categories": [
#                 {
#                     "alias": "lounges",
#                     "title": "Lounges"
#                 },
#                 {
#                     "alias": "venues",
#                     "title": "Venues & Event Spaces"
#                 },
#                 {
#                     "alias": "breakfast_brunch",
#                     "title": "Breakfast & Brunch"
#                 }
#             ],
#             "rating": 4.1,
#             "coordinates": {
#                 "latitude": 49.28232,
#                 "longitude": -123.12281
#             },
#             "transactions": [],
#             "price": "$$$",
#             "location": {
#                 "address1": "845 Hornby Street",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Vancouver",
#                 "zip_code": "V6Z 1T9",
#                 "country": "CA",
#                 "state": "BC",
#                 "display_address": [
#                     "845 Hornby Street",
#                     "Vancouver, BC V6Z 1T9",
#                     "Canada"
#                 ]
#             },
#             "phone": "+16046085319",
#             "display_phone": "+1 604-608-5319",
#             "distance": 155.25058895734753,
#             "business_hours": [
#                 {
#                     "open": [
#                         {
#                             "is_overnight": false,
#                             "start": "0700",
#                             "end": "0000",
#                             "day": 0
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "0700",
#                             "end": "0000",
#                             "day": 1
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "0700",
#                             "end": "0000",
#                             "day": 2
#                         },
#                         {
#                             "is_overnight": true,
#                             "start": "0700",
#                             "end": "0100",
#                             "day": 3
#                         },
#                         {
#                             "is_overnight": true,
#                             "start": "0700",
#                             "end": "0100",
#                             "day": 4
#                         },
#                         {
#                             "is_overnight": true,
#                             "start": "0700",
#                             "end": "0100",
#                             "day": 5
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "0700",
#                             "end": "0000",
#                             "day": 6
#                         }
#                     ],
#                     "hours_type": "REGULAR",
#                     "is_open_now": true
#                 }
#             ],
#             "attributes": {
#                 "business_temp_closed": null,
#                 "menu_url": "https://www.wedgewoodhotel.com/dining/bacchus-restaurant/#menu",
#                 "open24_hours": null,
#                 "waitlist_reservation": null
#             }
#         },
#         {
#             "id": "2cXOMeyBCx4JFgs5-CJQdQ",
#             "alias": "joe-fortes-seafood-and-chop-house-vancouver",
#             "name": "Joe Fortes Seafood & Chop House",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/YwNxIcGPKEvhvCGYBbMEWw/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/joe-fortes-seafood-and-chop-house-vancouver?adjust_creative=7NCke8zvVGD8HWvkWm6oXw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7NCke8zvVGD8HWvkWm6oXw",
#             "review_count": 1387,
#             "categories": [
#                 {
#                     "alias": "seafood",
#                     "title": "Seafood"
#                 },
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 49.284968691771624,
#                 "longitude": -123.12455980835064
#             },
#             "transactions": [],
#             "price": "$$$",
#             "location": {
#                 "address1": "777 Thurlow Street",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Vancouver",
#                 "zip_code": "V6E 3V5",
#                 "country": "CA",
#                 "state": "BC",
#                 "display_address": [
#                     "777 Thurlow Street",
#                     "Vancouver, BC V6E 3V5",
#                     "Canada"
#                 ]
#             },
#             "phone": "+16046691940",
#             "display_phone": "+1 604-669-1940",
#             "distance": 376.8549395724501,
#             "business_hours": [
#                 {
#                     "open": [
#                         {
#                             "is_overnight": false,
#                             "start": "1100",
#                             "end": "2300",
#                             "day": 0
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1100",
#                             "end": "2300",
#                             "day": 1
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1100",
#                             "end": "2300",
#                             "day": 2
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1100",
#                             "end": "2300",
#                             "day": 3
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1100",
#                             "end": "2300",
#                             "day": 4
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1100",
#                             "end": "2300",
#                             "day": 5
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1100",
#                             "end": "2300",
#                             "day": 6
#                         }
#                     ],
#                     "hours_type": "REGULAR",
#                     "is_open_now": true
#                 }
#             ],
#             "attributes": {
#                 "business_temp_closed": null,
#                 "menu_url": "http://www.joefortes.ca/menus",
#                 "open24_hours": null,
#                 "waitlist_reservation": true
#             }
#         },
#         {
#             "id": "LCQNNtLbY7Sa5zQI4nZPfg",
#             "alias": "hys-steakhouse-and-cocktail-bar-vancouver-3",
#             "name": "Hy's Steakhouse & Cocktail Bar",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/-1JAOg1O-Yls5-IUiZJ2rQ/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/hys-steakhouse-and-cocktail-bar-vancouver-3?adjust_creative=7NCke8zvVGD8HWvkWm6oXw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7NCke8zvVGD8HWvkWm6oXw",
#             "review_count": 386,
#             "categories": [
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 },
#                 {
#                     "alias": "cocktailbars",
#                     "title": "Cocktail Bars"
#                 },
#                 {
#                     "alias": "seafood",
#                     "title": "Seafood"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 49.28468,
#                 "longitude": -123.11927
#             },
#             "transactions": [],
#             "price": "$$$$",
#             "location": {
#                 "address1": "637 Hornby Street",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Vancouver",
#                 "zip_code": "V6C 2G3",
#                 "country": "CA",
#                 "state": "BC",
#                 "display_address": [
#                     "637 Hornby Street",
#                     "Vancouver, BC V6C 2G3",
#                     "Canada"
#                 ]
#             },
#             "phone": "+16046837671",
#             "display_phone": "+1 604-683-7671",
#             "distance": 238.65226266763756,
#             "business_hours": [
#                 {
#                     "open": [
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "2100",
#                             "day": 0
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "2100",
#                             "day": 1
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "2100",
#                             "day": 2
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "2100",
#                             "day": 3
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "2100",
#                             "day": 4
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1600",
#                             "end": "2100",
#                             "day": 5
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1600",
#                             "end": "2100",
#                             "day": 6
#                         }
#                     ],
#                     "hours_type": "REGULAR",
#                     "is_open_now": false
#                 }
#             ],
#             "attributes": {
#                 "business_temp_closed": null,
#                 "menu_url": "https://hyssteakhouse.com/menus/vancouver",
#                 "open24_hours": null,
#                 "waitlist_reservation": null
#             }
#         },
#         {
#             "id": "ai3DojYIZ8UQqBUFLSNdQg",
#             "alias": "black-and-blue-vancouver",
#             "name": "Black & Blue",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/OOF9Ebf0EL2rijU7KxfKyw/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/black-and-blue-vancouver?adjust_creative=7NCke8zvVGD8HWvkWm6oXw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7NCke8zvVGD8HWvkWm6oXw",
#             "review_count": 804,
#             "categories": [
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 },
#                 {
#                     "alias": "desserts",
#                     "title": "Desserts"
#                 },
#                 {
#                     "alias": "cocktailbars",
#                     "title": "Cocktail Bars"
#                 }
#             ],
#             "rating": 3.5,
#             "coordinates": {
#                 "latitude": 49.2845587688053,
#                 "longitude": -123.122869190308
#             },
#             "transactions": [],
#             "price": "$$$$",
#             "location": {
#                 "address1": "1032 Alberni Street",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Vancouver",
#                 "zip_code": "V6E 1A3",
#                 "country": "CA",
#                 "state": "BC",
#                 "display_address": [
#                     "1032 Alberni Street",
#                     "Vancouver, BC V6E 1A3",
#                     "Canada"
#                 ]
#             },
#             "phone": "+16046370777",
#             "display_phone": "+1 604-637-0777",
#             "distance": 259.75908911587885,
#             "business_hours": [
#                 {
#                     "open": [
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "2300",
#                             "day": 0
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "2300",
#                             "day": 1
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "2300",
#                             "day": 2
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "2300",
#                             "day": 3
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "0000",
#                             "day": 4
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "0000",
#                             "day": 5
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "2300",
#                             "day": 6
#                         }
#                     ],
#                     "hours_type": "REGULAR",
#                     "is_open_now": true
#                 }
#             ],
#             "attributes": {
#                 "business_temp_closed": null,
#                 "menu_url": "http://www.glowbalgroup.com/blackblue/#menu-section",
#                 "open24_hours": null,
#                 "waitlist_reservation": null
#             }
#         },
#         {
#             "id": "KXCXaF5qimmtKKqnPc_LQA",
#             "alias": "thierry-vancouver-9",
#             "name": "Thierry",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/K9u18jUx8Yfx13FFaQg5oA/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/thierry-vancouver-9?adjust_creative=7NCke8zvVGD8HWvkWm6oXw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7NCke8zvVGD8HWvkWm6oXw",
#             "review_count": 1019,
#             "categories": [
#                 {
#                     "alias": "cakeshop",
#                     "title": "Patisserie/Cake Shop"
#                 },
#                 {
#                     "alias": "cafes",
#                     "title": "Cafes"
#                 },
#                 {
#                     "alias": "chocolate",
#                     "title": "Chocolatiers & Shops"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 49.2848818,
#                 "longitude": -123.1228949
#             },
#             "transactions": [],
#             "price": "$$",
#             "location": {
#                 "address1": "1059 Alberni Street",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Vancouver",
#                 "zip_code": "V6E 1A1",
#                 "country": "CA",
#                 "state": "BC",
#                 "display_address": [
#                     "1059 Alberni Street",
#                     "Vancouver, BC V6E 1A1",
#                     "Canada"
#                 ]
#             },
#             "phone": "+16046086870",
#             "display_phone": "+1 604-608-6870",
#             "distance": 280.37196788747855,
#             "business_hours": [
#                 {
#                     "open": [
#                         {
#                             "is_overnight": false,
#                             "start": "0800",
#                             "end": "2200",
#                             "day": 0
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "0800",
#                             "end": "2200",
#                             "day": 1
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "0800",
#                             "end": "2200",
#                             "day": 2
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "0800",
#                             "end": "2200",
#                             "day": 3
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "0800",
#                             "end": "2300",
#                             "day": 4
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "0800",
#                             "end": "2300",
#                             "day": 5
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "0800",
#                             "end": "2200",
#                             "day": 6
#                         }
#                     ],
#                     "hours_type": "REGULAR",
#                     "is_open_now": true
#                 }
#             ],
#             "attributes": {
#                 "business_temp_closed": null,
#                 "menu_url": "http://www.thierrychocolates.com/cafe/menu/",
#                 "open24_hours": null,
#                 "waitlist_reservation": null
#             }
#         },
#         {
#             "id": "4EV_ZcQmjAmP3pmO-_nb2A",
#             "alias": "miku-vancouver-2",
#             "name": "Miku",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/sqGkH8tXc24UeDj24zRSyw/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/miku-vancouver-2?adjust_creative=7NCke8zvVGD8HWvkWm6oXw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7NCke8zvVGD8HWvkWm6oXw",
#             "review_count": 2457,
#             "categories": [
#                 {
#                     "alias": "japanese",
#                     "title": "Japanese"
#                 },
#                 {
#                     "alias": "sushi",
#                     "title": "Sushi Bars"
#                 }
#             ],
#             "rating": 4.4,
#             "coordinates": {
#                 "latitude": 49.28691298612272,
#                 "longitude": -123.11304877258942
#             },
#             "transactions": [],
#             "price": "$$$",
#             "location": {
#                 "address1": "200 Granville Street",
#                 "address2": "Suite 70",
#                 "address3": "",
#                 "city": "Vancouver",
#                 "zip_code": "V6C 1S4",
#                 "country": "CA",
#                 "state": "BC",
#                 "display_address": [
#                     "200 Granville Street",
#                     "Suite 70",
#                     "Vancouver, BC V6C 1S4",
#                     "Canada"
#                 ]
#             },
#             "phone": "+16045683900",
#             "display_phone": "+1 604-568-3900",
#             "distance": 726.2497457954859,
#             "business_hours": [
#                 {
#                     "open": [
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "2200",
#                             "day": 0
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "2200",
#                             "day": 1
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "2200",
#                             "day": 2
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "2200",
#                             "day": 3
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "2200",
#                             "day": 4
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1200",
#                             "end": "2200",
#                             "day": 5
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1200",
#                             "end": "2200",
#                             "day": 6
#                         }
#                     ],
#                     "hours_type": "REGULAR",
#                     "is_open_now": true
#                 }
#             ],
#             "attributes": {
#                 "business_temp_closed": null,
#                 "menu_url": "https://mikurestaurant.com/menu-main",
#                 "open24_hours": null,
#                 "waitlist_reservation": null
#             }
#         },
#         {
#             "id": "VPqWLp9kMiZEbctCebIZUA",
#             "alias": "medina-cafe-vancouver",
#             "name": "Medina Cafe",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/lnRDp4KU_p1ldlLm_--a7w/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/medina-cafe-vancouver?adjust_creative=7NCke8zvVGD8HWvkWm6oXw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7NCke8zvVGD8HWvkWm6oXw",
#             "review_count": 2748,
#             "categories": [
#                 {
#                     "alias": "breakfast_brunch",
#                     "title": "Breakfast & Brunch"
#                 },
#                 {
#                     "alias": "mideastern",
#                     "title": "Middle Eastern"
#                 },
#                 {
#                     "alias": "wine_bars",
#                     "title": "Wine Bars"
#                 }
#             ],
#             "rating": 4.2,
#             "coordinates": {
#                 "latitude": 49.2804429972571,
#                 "longitude": -123.117036269849
#             },
#             "transactions": [],
#             "price": "$$",
#             "location": {
#                 "address1": "780 Richards Street",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Vancouver",
#                 "zip_code": "V6B 3A4",
#                 "country": "CA",
#                 "state": "BC",
#                 "display_address": [
#                     "780 Richards Street",
#                     "Vancouver, BC V6B 3A4",
#                     "Canada"
#                 ]
#             },
#             "phone": "+16048793114",
#             "display_phone": "+1 604-879-3114",
#             "distance": 365.5281063549046,
#             "business_hours": [
#                 {
#                     "open": [
#                         {
#                             "is_overnight": false,
#                             "start": "0800",
#                             "end": "1500",
#                             "day": 0
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "0800",
#                             "end": "1500",
#                             "day": 1
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "0800",
#                             "end": "1500",
#                             "day": 2
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "0800",
#                             "end": "1500",
#                             "day": 3
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "0800",
#                             "end": "1500",
#                             "day": 4
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "0900",
#                             "end": "1500",
#                             "day": 5
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "0900",
#                             "end": "1500",
#                             "day": 6
#                         }
#                     ],
#                     "hours_type": "REGULAR",
#                     "is_open_now": false
#                 }
#             ],
#             "attributes": {
#                 "business_temp_closed": null,
#                 "menu_url": "",
#                 "open24_hours": null,
#                 "waitlist_reservation": null
#             }
#         },
#         {
#             "id": "n7cBSlfu_utOVK3QZCCWrQ",
#             "alias": "1931-gallery-bistro-vancouver",
#             "name": "1931 Gallery Bistro",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/t0Jjm49icEFcsBYPOEXsHg/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/1931-gallery-bistro-vancouver?adjust_creative=7NCke8zvVGD8HWvkWm6oXw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7NCke8zvVGD8HWvkWm6oXw",
#             "review_count": 59,
#             "categories": [
#                 {
#                     "alias": "breakfast_brunch",
#                     "title": "Breakfast & Brunch"
#                 },
#                 {
#                     "alias": "bistros",
#                     "title": "Bistros"
#                 }
#             ],
#             "rating": 3.7,
#             "coordinates": {
#                 "latitude": 49.2830721,
#                 "longitude": -123.1208098
#             },
#             "transactions": [],
#             "location": {
#                 "address1": "750 Hornby Street",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Vancouver",
#                 "zip_code": "V6Z 2H7",
#                 "country": "CA",
# ...
#                             "end": "1100",
#                             "day": 4
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "1400",
#                             "day": 4
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1700",
#                             "end": "2130",
#                             "day": 4
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "0630",
#                             "end": "1100",
#                             "day": 5
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "1400",
#                             "day": 5
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1700",
#                             "end": "2130",
#                             "day": 5
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "0630",
#                             "end": "1100",
#                             "day": 6
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "1400",
#                             "day": 6
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1700",
#                             "end": "2130",
#                             "day": 6
#                         }
#                     ],
#                     "hours_type": "REGULAR",
#                     "is_open_now": false
#                 }
#             ],
#             "attributes": {
#                 "business_temp_closed": null,
#                 "menu_url": null,
#                 "open24_hours": null,
#                 "waitlist_reservation": null
#             }
#         },
#         {
#             "id": "htvl5L_V-zKN0UvUgP60PQ",
#             "alias": "robba-da-matti-vancouver",
#             "name": "Robba da Matti",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/2OAP0M4yXfLkVGMfBDoUcA/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/robba-da-matti-vancouver?adjust_creative=7NCke8zvVGD8HWvkWm6oXw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7NCke8zvVGD8HWvkWm6oXw",
#             "review_count": 544,
#             "categories": [
#                 {
#                     "alias": "italian",
#                     "title": "Italian"
#                 },
#                 {
#                     "alias": "tapas",
#                     "title": "Tapas Bars"
#                 }
#             ],
#             "rating": 4.2,
#             "coordinates": {
#                 "latitude": 49.2753397,
#                 "longitude": -123.1208967
#             },
#             "transactions": [],
#             "price": "$$",
#             "location": {
#                 "address1": "1127 Mainland Street",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Vancouver",
#                 "zip_code": "V6B 5P2",
#                 "country": "CA",
#                 "state": "BC",
#                 "display_address": [
#                     "1127 Mainland Street",
#                     "Vancouver, BC V6B 5P2",
#                     "Canada"
#                 ]
#             },
#             "phone": "+16045581174",
#             "display_phone": "+1 604-558-1174",
#             "distance": 818.5514851500948,
#             "business_hours": [
#                 {
#                     "open": [
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "1500",
#                             "day": 0
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1700",
#                             "end": "2100",
#                             "day": 0
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "1500",
#                             "day": 1
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1700",
#                             "end": "2100",
#                             "day": 1
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "1500",
#                             "day": 2
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1700",
#                             "end": "2100",
#                             "day": 2
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "1500",
#                             "day": 3
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1700",
#                             "end": "2100",
#                             "day": 3
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "1500",
#                             "day": 4
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1700",
#                             "end": "2200",
#                             "day": 4
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "1500",
#                             "day": 5
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1700",
#                             "end": "2200",
#                             "day": 5
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "1500",
#                             "day": 6
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1700",
#                             "end": "2100",
#                             "day": 6
#                         }
#                     ],
#                     "hours_type": "REGULAR",
#                     "is_open_now": false
#                 }
#             ],
#             "attributes": {
#                 "business_temp_closed": null,
#                 "menu_url": null,
#                 "open24_hours": null,
#                 "waitlist_reservation": null
#             }
#         },
#         {
#             "id": "DuA0zfuD2wsuZbDdQj3I8w",
#             "alias": "the-keg-steakhouse-bar-dunsmuir-vancouver-5",
#             "name": "The Keg Steakhouse + Bar - Dunsmuir",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/0xcmD5tNjkS88Xf32uk4bg/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/the-keg-steakhouse-bar-dunsmuir-vancouver-5?adjust_creative=7NCke8zvVGD8HWvkWm6oXw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7NCke8zvVGD8HWvkWm6oXw",
#             "review_count": 213,
#             "categories": [
#                 {
#                     "alias": "seafood",
#                     "title": "Seafood"
#                 },
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 },
#                 {
#                     "alias": "bars",
#                     "title": "Bars"
#                 }
#             ],
#             "rating": 3.8,
#             "coordinates": {
#                 "latitude": 49.283455277246034,
#                 "longitude": -123.11635967248964
#             },
#             "transactions": [],
#             "price": "$$$",
#             "location": {
#                 "address1": "688 Dunsmuir Street",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Vancouver",
#                 "zip_code": "V6B 1N3",
#                 "country": "CA",
#                 "state": "BC",
#                 "display_address": [
#                     "688 Dunsmuir Street",
#                     "Vancouver, BC V6B 1N3",
#                     "Canada"
#                 ]
#             },
#             "phone": "+16046857502",
#             "display_phone": "+1 604-685-7502",
#             "distance": 325.8341738636107,
#             "business_hours": [
#                 {
#                     "open": [
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "2230",
#                             "day": 0
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "2230",
#                             "day": 1
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "2230",
#                             "day": 2
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "2230",
#                             "day": 3
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "2330",
#                             "day": 4
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1600",
#                             "end": "2330",
#                             "day": 5
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1600",
#                             "end": "2230",
#                             "day": 6
#                         }
#                     ],
#                     "hours_type": "REGULAR",
#                     "is_open_now": false
#                 }
#             ],
#             "attributes": {
#                 "business_temp_closed": null,
#                 "menu_url": "https://www.thekeg.com/en/locations/dunsmuir/menu",
#                 "open24_hours": null,
#                 "waitlist_reservation": null
#             }
#         },
#         {
#             "id": "iid0VenH7rIp3AWuyQAAHw",
#             "alias": "saku-vancouver-9",
#             "name": "Saku",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/s75mQzW-VtCf2LPSxrvkWQ/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/saku-vancouver-9?adjust_creative=7NCke8zvVGD8HWvkWm6oXw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7NCke8zvVGD8HWvkWm6oXw",
#             "review_count": 480,
#             "categories": [
#                 {
#                     "alias": "japanese",
#                     "title": "Japanese"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 49.289223,
#                 "longitude": -123.132266
#             },
#             "transactions": [],
#             "price": "$$",
#             "location": {
#                 "address1": "1588 Robson Street",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Vancouver",
#                 "zip_code": "V6G 2G5",
#                 "country": "CA",
#                 "state": "BC",
#                 "display_address": [
#                     "1588 Robson Street",
#                     "Vancouver, BC V6G 2G5",
#                     "Canada"
#                 ]
#             },
#             "phone": "+17783795872",
#             "display_phone": "+1 778-379-5872",
#             "distance": 1107.4847484854074,
#             "business_hours": [
#                 {
#                     "open": [
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "1500",
#                             "day": 0
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1700",
#                             "end": "2130",
#                             "day": 0
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "1500",
#                             "day": 1
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1700",
#                             "end": "2130",
#                             "day": 1
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "1500",
#                             "day": 2
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1700",
#                             "end": "2130",
#                             "day": 2
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "1500",
#                             "day": 3
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1700",
#                             "end": "2130",
#                             "day": 3
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "2130",
#                             "day": 4
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "2130",
#                             "day": 5
#                         },
#                         {
#                             "is_overnight": false,
#                             "start": "1130",
#                             "end": "2130",
#                             "day": 6
#                         }
#                     ],
#                     "hours_type": "REGULAR",
#                     "is_open_now": true
#                 }
#             ],
#             "attributes": {
#                 "business_temp_closed": null,
#                 "menu_url": "https://www.sakuvancouver.com/menus",
#                 "open24_hours": null,
#                 "waitlist_reservation": null
#             }
#         }
#     ],
#     "total": 1500,
#     "region": {
#         "center": {
#             "longitude": -123.1207,
#             "latitude": 49.2827
#         }
#     }
# }

# %% [markdown]
# Comparing Results:
# Which API provided you with more complete data? Provide an explanation.
#
# The Yelp API had a larger number of results than the Foursquare API, and included elements such as number of reviews.
# Both APIs had reasonably low levels of null values. Most null values occurred when merging the results from the two APIs.
